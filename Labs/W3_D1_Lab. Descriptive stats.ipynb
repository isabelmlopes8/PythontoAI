# %% [markdown]
# # Before you start :
#    - These exercises are related to the Subsetting and Descriptive Stats lessons.
#    - Keep in mind that you need to use some of the functions you learned in the previous lessons.
#    - All datasets are provided in the `your-code` folder of this lab.
#    - Elaborate your codes and outputs as much as you can.
#    - Try your best to answer the questions and complete the tasks and most importantly enjoy the process!!!

# %% [markdown]
# #### Import all the libraries that are necessary

# %%
# import libraries here

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Challenge 1

# %% [markdown]
# #### In this challenge we will use the `Temp_States.csv` file.
#
# #### First import it into a data frame called `temp`.

# %%
# YOUR CODE HERE


temp = pd.read_csv('C:/Users/isabel.lopes/OneDrive - XPLOR SOLUTIONS/PythonForAISolutions/WEEK3/DAY1/Temp_States.csv')

# %% [markdown]
# #### Print `temp`

# %%
# your solution here

print(temp)
# Out:
#          City        State  Temperature
# 0         NYC     New York    19.444444
# 1      Albany     New York     9.444444
# 2     Buffalo     New York     3.333333
# 3    Hartford  Connecticut    17.222222
# 4  Bridgeport  Connecticut    14.444444
# 5      Treton   New Jersey    22.222222
# 6      Newark   New Jersey    20.000000

# %% [markdown]
# #### Explore the data types of the Temp dataframe. What type of data do we have? Comment your result.

# %%
# YOUR CODE HERE

temp.describe()

#Both "City" and "Temperature" are objects which means there can be information associated to them
# Out:
#        Temperature
# count     7.000000
# mean     15.158730
# std       6.695265
# min       3.333333
# 25%      11.944444
# 50%      17.222222
# 75%      19.722222
# max      22.222222

# %% [markdown]
# #### Select the rows where state is New York

# %%
# YOUR CODE HERE

temp_NY = temp[temp ['State']=="New York"]

print(temp_NY )
# Out:
#       City     State  Temperature
# 0      NYC  New York    19.444444
# 1   Albany  New York     9.444444
# 2  Buffalo  New York     3.333333

# %% [markdown]
# #### What is the average of the temperature of cities in New York?

# %%
# YOUR CODE HERE

average_temp_ny_state = temp_NY['Temperature'].mean()

print(f"The average f the temperature of cities in New York is {average_temp_ny_state}")
# Out:
# The average f the temperature of cities in New York is 10.74074074074074

# %% [markdown]
# #### We want to know cities and states with Temperature above 15 degress Celcius

# %%
# your answer here

cities_ststaes_above_15 = temp[temp['Temperature'] > 15]

print(cities_ststaes_above_15[['City','State']]  )
# Out:
#        City        State
# 0       NYC     New York
# 3  Hartford  Connecticut
# 5    Treton   New Jersey
# 6    Newark   New Jersey

# %% [markdown]
# #### Now, return only the cities that have a temperature above 15 degress Celcius

# %%
# YOUR CODE HERE

print(cities_ststaes_above_15['City']  )
# Out:
# 0         NYC
# 3    Hartford
# 5      Treton
# 6      Newark
# Name: City, dtype: object

# %% [markdown]
# #### We want to know which cities have a temperature above 15 degrees Celcius and below 20 degrees Celcius
#
# *Hint: First write the condition then select the rows.*

# %%
# YOUR CODE HERE


cities_ststaes_above_15_below_20 = temp[(temp['Temperature'] > 15) & (temp['Temperature'] < 20)]

print(cities_ststaes_above_15_below_20['City'])
# Out:
# 0         NYC
# 3    Hartford
# Name: City, dtype: object

# %%
temp['State'].value_counts()
# Out:
# State
# New York       3
# Connecticut    2
# New Jersey     2
# Name: count, dtype: int64

# %% [markdown]
# #### Find the mean and the standard deviation of the temperature of each state.
#
# *Hint: Use functions from Data Manipulation lesson*

# %%
# YOUR CODE HERE

temp_state = temp.groupby('State')['Temperature'].agg('mean','std')

print(temp_state)




#print(temp_state.mean())

#print(temp_state.std())
# Out:
# State
# Connecticut    15.833333
# New Jersey     21.111111
# New York       10.740741
# Name: Temperature, dtype: float64

# %% [markdown]
# # Challenge 2

# %% [markdown]
# #### Load the `employee.csv` file into a DataFrame. Call the dataframe `employee`

# %%
# YOUR CODE HERE


employee = pd.read_csv('C:/Users/isabel.lopes/OneDrive - XPLOR SOLUTIONS/PythonForAISolutions/WEEK3/DAY1/Employee.csv')

# %% [markdown]
# #### Explore the data types of the Temp dataframe. Comment your results

# %%
# YOUR CODE HERE

print(employee.dtypes)
# Out:
# Name          object
# Department    object
# Education     object
# Gender        object
# Title         object
# Years          int64
# Salary         int64
# dtype: object

# %% [markdown]
# #### Show visually the frequency distribution (histogram) of the employee dataset. In few words describe these histograms?

# %%
# your answer here

# %%
# YOUR CODE HERE



employee['Department'].hist(bins=6, edgecolor='black')
plt.title('No people per department')
plt.xlabel('Department')
plt.ylabel('Frequency')
plt.show()



employee['Gender'].hist(bins=4, edgecolor='black')
plt.title('No people per department')
plt.xlabel('Department')
plt.ylabel('Frequency')
plt.show()

employee['Title'].hist(bins=37, edgecolor='black')
plt.title('No people per department')
plt.xlabel('Department')
plt.ylabel('Frequency')
plt.show()

# %%
# YOUR CODE HERE

# %% [markdown]
# #### What's the average salary in this company?

# %%
# YOUR CODE HERE

Average_salary= employee['Salary'].mean()

print(f"The average salary is {Average_salary}")
# Out:
# The average salary is 48.888888888888886

# %% [markdown]
# #### What's the highest salary?

# %%
# YOUR CODE HERE

highest_salary = employee['Salary'].max()

print(f"The highest salary is {highest_salary}")
# Out:
# The highest salary is 70

# %% [markdown]
# #### What's the lowest salary?

# %%
# YOUR CODE HERE

lowest_salary = employee['Salary'].min()

print(f"The minimum salary is {lowest_salary}")
# Out:
# The minimum salary is 30

# %% [markdown]
# #### Who are the employees with the lowest salary?

# %%
# YOUR CODE HERE

employee[employee['Salary'] == lowest_salary]['Name']
# Out:
# 1    Maria
# 2    David
# Name: Name, dtype: object

# %% [markdown]
# #### Could you give all the information about an employee called David?

# %%
# YOUR CODE HERE

employee[employee['Name'] == "David"]
# Out:
#     Name Department Education Gender    Title  Years  Salary
# 2  David         HR    Master      M  analyst      2      30

# %% [markdown]
# #### Could you give only David's salary?

# %%
# YOUR CODE HERE

employee[employee['Name'] == "David"]['Salary']
# Out:
# 2    30
# Name: Salary, dtype: int64

# %% [markdown]
# #### Print all the rows where job title is associate

# %%
# YOUR CODE HERE

employee[employee['Title'] == "associate"]
# Out:
#      Name Department Education Gender      Title  Years  Salary
# 4  Samuel      Sales    Master      M  associate      3      55
# 5     Eva      Sales  Bachelor      F  associate      2      55
# 7   Pedro         IT       Phd      M  associate      7      60

# %% [markdown]
# #### Print the first 3 rows of your dataframe
#
# ##### Tip : There are 2 ways to do it. Do it both ways

# %%
# YOUR CODE HERE

employee.head(3)
# Out:
#     Name Department Education Gender    Title  Years  Salary
# 0   Jose         IT  Bachelor      M  analyst      1      35
# 1  Maria         IT    Master      F  analyst      2      30
# 2  David         HR    Master      M  analyst      2      30

# %%
# YOUR CODE HERE

employee.iloc[:3]
# Out:
#     Name Department Education Gender    Title  Years  Salary
# 0   Jose         IT  Bachelor      M  analyst      1      35
# 1  Maria         IT    Master      F  analyst      2      30
# 2  David         HR    Master      M  analyst      2      30

# %% [markdown]
# #### Find the employees who's title is associate and the salary above 55?

# %%
# YOUR CODE HERE

employee[(employee['Title'] == "associate") & (employee['Salary'] > 55)]
# Out:
#     Name Department Education Gender      Title  Years  Salary
# 7  Pedro         IT       Phd      M  associate      7      60

# %% [markdown]
# #### Group the employees based on their number of years of employment. What are the average salaries in each group?

# %%
# YOUR CODE HERE

employee_years_average = employee.groupby('Years')['Salary'].agg('mean')

print(employee_years_average)
# Out:
# Years
# 1    35.000000
# 2    38.333333
# 3    55.000000
# 4    35.000000
# 7    60.000000
# 8    70.000000
# Name: Salary, dtype: float64

# %% [markdown]
# ####  What is the average Salary per title?

# %%
# YOUR CODE HERE

employee_title_average = employee.groupby('Title')['Salary'].agg('mean')

print(employee_title_average)
# Out:
# Title
# VP           70.000000
# analyst      32.500000
# associate    56.666667
# Name: Salary, dtype: float64

# %% [markdown]
# #### Show a visual summary of the data using boxplot. What Are the First and Third Quartiles? Comment your results.
#
# * Hint : Quantiles vs Quartiles*
# In Probability and Statistics, quantiles are cut points dividing the range of a probability distribution into continuous intervals with equal probabilities. When division is into four parts the values of the variate corresponding to 25%, 50% and 75% of the total distribution are called quartiles.

# %%
# YOUR CODE HERE

plt.figure(figsize=(10, 6))
sns.boxplot(x=employee['Salary'])
plt.title('Boxplot of Employee Salary')
plt.xlabel('Salary')
plt.show()
# Out:
# First Quartile (Q1): 35.0
# Third Quartile (Q3): 60.0

# %%
# print first quartile here


Q1 = employee['Salary'].quantile(0.25)


print(f"First Quartile (Q1): {Q1}")
# Out:
# First Quartile (Q1): 35.0

# %%
# print third quartile here

Q3 = employee['Salary'].quantile(0.75)
print(f"Third Quartile (Q3): {Q3}")
# Out:
# Third Quartile (Q3): 60.0

# %% [markdown]
# #### Is the mean salary per gender different?

# %%
# your answer here

employee_gender_average = employee.groupby('Gender')['Salary'].agg('mean')

print(employee_gender_average)
# Out:
# Gender
# F    47.5
# M    50.0
# Name: Salary, dtype: float64

# %% [markdown]
# #### Find the minimum, mean and the maximum of all numeric columns for each Department.
#
# ##### Hint: Use functions from Data Manipulation lesson

# %%
# your answer here

employee_department_numeric = employee.groupby('Department').agg({
    'Years': ['min', 'mean', 'max'],
    'Salary': ['min', 'mean', 'max']
})

print(employee_department_numeric)
# Out:
#            Years               Salary
#              min      mean max    min   mean max
# Department
# HR             2  4.666667   8     30  45.00  70
# IT             1  4.500000   8     30  48.75  70
# Sales          2  2.500000   3     55  55.00  55

# %% [markdown]
# ### Bonus Question
#
# #### For each department, compute the difference between the maximal salary and the minimal salary.
#
# ##### * Hint: try using `agg` or `apply` and `lambda`*

# %%
# your answer here

employee_salary_diff = employee.groupby('Department')['Salary'].agg(lambda x: x.max() - x.min()).reset_index()
employee_salary_diff.columns = ['Department', 'Salary Difference']

print(employee_salary_diff)
# Out:
#   Department  Salary Difference
# 0         HR                 40
# 1         IT                 40
# 2      Sales                  0

# %% [markdown]
# # Challenge 3

# %% [markdown]
# #### Open the Orders.csv dataset. Name your dataset orders

# %%
# your answer here

orders = pd.read_csv('C:/Users/isabel.lopes/OneDrive - XPLOR SOLUTIONS/PythonForAISolutions/WEEK3/DAY1/Orders.csv')

# %% [markdown]
# #### Explore your dataset by looking at the data types and the summary statistics. Comment your results

# %%
# your answer here

orders.describe()
# Out:
#           Unnamed: 0      InvoiceNo           year          month  \
# count  397924.000000  397924.000000  397924.000000  397924.000000
# mean   278465.221859  560617.126645    2010.934259       7.612537
# std    152771.368303   13106.167695       0.247829       3.416527
# min         0.000000  536365.000000    2010.000000       1.000000
# 25%    148333.750000  549234.000000    2011.000000       5.000000
# 50%    284907.500000  561893.000000    2011.000000       8.000000
# 75%    410079.250000  572090.000000    2011.000000      11.000000
# max    541908.000000  581587.000000    2011.000000      12.000000
#
#                  day           hour       Quantity      UnitPrice  \
# count  397924.000000  397924.000000  397924.000000  397924.000000
# mean        3.614555      12.728247      13.021823       3.116174
# std         1.928274       2.273535     180.420210      22.096788
# min         1.000000       6.000000       1.000000       0.000000
# ...

# %%
# your answer here

# %% [markdown]
# ####  What is the average Purchase Price?

# %%
# your answer here

print(orders['UnitPrice'].mean())
# Out:
# 3.1161744805540756

# %% [markdown]
# #### What were the highest and lowest purchase prices?

# %%
# your answer here

print(f"THe highest price is {orders['UnitPrice'].max()}")
# Out:
# THe highest price is 8142.75

# %%
# your answer here

print(f"THe lowest price is {orders['UnitPrice'].min()}")
# Out:
# THe lowest price is 0.0

# %% [markdown]
# #### Select all the customers we have in Spain

# %%
# your answer here

orders[orders['Country']== "Spain"]
# Out:
#         Unnamed: 0  InvoiceNo StockCode  year  month  day  hour  \
# 4250          6421     536944     22383  2010     12    5    12
# 4251          6422     536944     22384  2010     12    5    12
# 4252          6423     536944     20727  2010     12    5    12
# 4253          6424     536944     20725  2010     12    5    12
# 4254          6425     536944     20728  2010     12    5    12
# ...            ...        ...       ...   ...    ...  ...   ...
# 394733      535271     581193     23291  2011     12    3    17
# 394734      535272     581193    85232D  2011     12    3    17
# 394735      535273     581193     22721  2011     12    3    17
# 394736      535274     581193     23241  2011     12    3    17
# 394737      535275     581193     23247  2011     12    3    17
#
#                           Description  Quantity          InvoiceDate  \
# 4250          lunch bag suki  design         70  2010-12-03 12:20:00
# ...

# %% [markdown]
# #### How many customers do we have in Spain?
# ##### Hint : Use value_counts()

# %%
# your answer here

orders[orders['Country']== "Spain"]['Country'].value_counts()
# Out:
# Country
# Spain    2485
# Name: count, dtype: int64

# %% [markdown]
# #### Select all the customers who have bought more than 50 items ?

# %%
# your answer here

orders[orders['Quantity'] > 50]
# Out:
#         Unnamed: 0  InvoiceNo StockCode  year  month  day  hour  \
# 46              46     536371     22086  2010     12    3     9
# 83              83     536376     21733  2010     12    3     9
# 96              96     536378     21212  2010     12    3     9
# 102            102     536378    85071B  2010     12    3     9
# 174            176     536386    85099C  2010     12    3     9
# ...            ...        ...       ...   ...    ...  ...   ...
# 397720      541702     581566     23404  2011     12    5    11
# 397721      541703     581567     21417  2011     12    5    11
# 397729      541711     581567     21326  2011     12    5    11
# 397761      541746     581571     23167  2011     12    5    12
# 397882      541867     581584     20832  2011     12    5    12
#
#                                Description  Quantity          InvoiceDate  \
# 46         paper chain kit 50's christmas         80  2010-12-01 09:00:00
# ...

# %% [markdown]
# #### Select orders from Spain that are above 50 items

# %%
# your answer here

orders[(orders['Quantity'] > 50) & (orders['Country']== "Spain")]
# Out:
#         Unnamed: 0  InvoiceNo StockCode  year  month  day  hour  \
# 4250          6421     536944     22383  2010     12    5    12
# 4251          6422     536944     22384  2010     12    5    12
# 4252          6423     536944     20727  2010     12    5    12
# 4253          6424     536944     20725  2010     12    5    12
# 4254          6425     536944     20728  2010     12    5    12
# 32454        52416     540785    84997B  2011      1    2    11
# 32455        52417     540785    84997D  2011      1    2    11
# 32456        52418     540785    84997C  2011      1    2    11
# 32457        52419     540785    84997A  2011      1    2    11
# 91155       136767     547972     22383  2011      3    1    16
# 91156       136768     547972     22384  2011      3    1    16
# 91159       136771     547972     20728  2011      3    1    16
# 174442      248797     558871     22384  2011      7    1    13
# 174443      248798     558871     20727  2011      7    1    13
# ...

# %% [markdown]
# #### Select all free orders

# %%
# your answer here

orders.columns = orders.columns.str.strip().str.replace(' ', '_').str.lower()

free_orders = orders[orders['unitprice']==0]

print(free_orders)
# Out:
#         unnamed:_0  invoiceno stockcode  year  month  day  hour  \
# 6914          9302     537197     22841  2010     12    7    14
# 22539        33576     539263     22580  2010     12    4    14
# 25379        40089     539722     22423  2010     12    2    13
# 29080        47068     540372     22090  2011      1    4    16
# 29082        47070     540372     22553  2011      1    4    16
# 34494        56674     541109     22168  2011      1    4    15
# 53788        86789     543599    84535B  2011      2    4    13
# 85671       130188     547417     22062  2011      3    3    10
# 92875       139453     548318     22055  2011      3    3    12
# 97430       145208     548871     22162  2011      4    1    14
# 107192      157042     550188     22636  2011      4    4    18
# 128641      187613     553000     47566  2011      5    4    15
# 137127      198383     554037     22619  2011      5    5    14
# 194648      279324     561284     22167  2011      7    2    12
# ...

# %% [markdown]
# #### Select all orders that are 'lunch bag'
# #### Hint: Use string functions

# %%
# your answer here

orders_lunchbag = orders[orders['description'].str.contains('lunch bag',case=False, na=False)]

print(orders_lunchbag)
# Out:
#         unnamed:_0  invoiceno stockcode  year  month  day  hour  \
# 93              93     536378     20725  2010     12    3     9
# 172            174     536385     22662  2010     12    3     9
# 354            363     536401     22662  2010     12    3    11
# 359            368     536401     20725  2010     12    3    11
# 360            369     536401     22382  2010     12    3    11
# ...            ...        ...       ...   ...    ...  ...   ...
# 397465      540436     581486     23207  2011     12    5     9
# 397713      541695     581538     20727  2011     12    5    11
# 397714      541696     581538     20725  2011     12    5    11
# 397877      541862     581581     23681  2011     12    5    12
# 397880      541865     581583     20725  2011     12    5    12
#
#                         description  quantity          invoicedate  unitprice  \
# 93          lunch bag red retrospot        10  2010-12-01 09:37:00       1.65
# ...

# %% [markdown]
# #### Select all orders that are made in 2011 and are 'lunch bag'

# %%
# your answer here

orders[(orders['quantity'] > 50) & (orders['country']== "Spain")]
# Out:
#         unnamed:_0  invoiceno stockcode  year  month  day  hour  \
# 4250          6421     536944     22383  2010     12    5    12
# 4251          6422     536944     22384  2010     12    5    12
# 4252          6423     536944     20727  2010     12    5    12
# 4253          6424     536944     20725  2010     12    5    12
# 4254          6425     536944     20728  2010     12    5    12
# 32454        52416     540785    84997B  2011      1    2    11
# 32455        52417     540785    84997D  2011      1    2    11
# 32456        52418     540785    84997C  2011      1    2    11
# 32457        52419     540785    84997A  2011      1    2    11
# 91155       136767     547972     22383  2011      3    1    16
# 91156       136768     547972     22384  2011      3    1    16
# 91159       136771     547972     20728  2011      3    1    16
# 174442      248797     558871     22384  2011      7    1    13
# 174443      248798     558871     20727  2011      7    1    13
# ...

# %% [markdown]
# #### Show the frequency distribution of the amount spent in Spain.

# %%
orders_spain = orders[orders['country'] == 'Spain']


amount_spent_spain = orders_spain['amount_spent']


amount_spent_spain.hist(bins=30, edgecolor='black')
plt.title('Amount Spent Distribution in Spain')
plt.xlabel('Amount Spent')
plt.ylabel('Frequency')




plt.show()

# %%
orders.head()
# Out:
#    unnamed:_0  invoiceno stockcode  year  month  day  hour  \
# 0           0     536365    85123A  2010     12    3     8
# 1           1     536365     71053  2010     12    3     8
# 2           2     536365    84406B  2010     12    3     8
# 3           3     536365    84029G  2010     12    3     8
# 4           4     536365    84029E  2010     12    3     8
#
#                            description  quantity          invoicedate  \
# 0   white hanging heart t-light holder         6  2010-12-01 08:26:00
# 1                  white metal lantern         6  2010-12-01 08:26:00
# 2       cream cupid hearts coat hanger         8  2010-12-01 08:26:00
# 3  knitted union flag hot water bottle         6  2010-12-01 08:26:00
# 4       red woolly hottie white heart.         6  2010-12-01 08:26:00
#
#    unitprice  customerid         country  amount_spent
# 0       2.55       17850  United Kingdom         15.30
# 1       3.39       17850  United Kingdom         20.34
# ...

# %% [markdown]
# #### Select all orders made in the month of August

# %%
# your answer here

orders[(orders['month'] == 8) ]
# Out:
#         unnamed:_0  invoiceno stockcode  year  month  day  hour  \
# 199475      285421     561904     22075  2011      8    1     8
# 199476      285422     561904    85049E  2011      8    1     8
# 199477      285423     561905     21385  2011      8    1     9
# 199478      285424     561905    84970L  2011      8    1     9
# 199479      285425     561905    84970S  2011      8    1     9
# ...            ...        ...       ...   ...    ...  ...   ...
# 226483      320688     565067     22644  2011      8    3    17
# 226484      320689     565067     22645  2011      8    3    17
# 226485      320690     565067     22637  2011      8    3    17
# 226486      320691     565067     22646  2011      8    3    17
# 226487      320692     565067     22741  2011      8    3    17
#
#                                 description  quantity          invoicedate  \
# 199475         6 ribbons elegant christmas         96  2011-08-01 08:30:00
# ...

# %% [markdown]
# #### Select how many orders are made by countries in the month of August
# ##### Hint: Use value_counts()

# %%
# your answer here

orders_august = orders[orders['month']== 8]

average_spend_per_country = orders_august['country'].value_counts()

print(average_spend_per_country)
# Out:
# country
# United Kingdom     23105
# Germany              795
# EIRE                 593
# France               569
# Netherlands          280
# Switzerland          267
# Spain                252
# Belgium              194
# Israel               171
# Channel Islands      140
# Australia            107
# Italy                 95
# Austria               88
# Norway                77
# Finland               61
# Malta                 55
# Portugal              41
# Sweden                40
# Unspecified           23
# Iceland               22
# Poland                17
# Denmark               16
# Canada                 5
# Name: count, dtype: int64

# %% [markdown]
# #### What's the  average amount of money spent by country

# %%
# your answer here

average_spend_per_country = orders.groupby('country')['amount_spent'].agg('mean')

print(average_spend_per_country)
# Out:
# country
# Australia               116.895620
# Austria                  25.624824
# Bahrain                  32.258824
# Belgium                  20.283772
# Brazil                   35.737500
# Canada                   24.280662
# Channel Islands          27.340160
# Cyprus                   22.134169
# Czech Republic           33.069600
# Denmark                  49.882474
# EIRE                     36.687745
# European Community       21.670833
# Finland                  32.913985
# France                   25.056827
# Germany                  25.311562
# Greece                   32.831172
# Iceland                  23.681319
# Israel                   29.119718
# Italy                    23.064960
# Japan                   116.561900
# Lebanon                  37.641778
# Lithuania                47.458857
# Malta                    24.335625
# Netherlands             120.798282
# Norway                   33.736418
# Poland                   22.226212
# ...

# %% [markdown]
# #### What's the most expensive item?

# %%
# your answer here

max_price_item = orders['unitprice'].max()

orders[orders['unitprice']==max_price_item]['description']
# Out:
# 118352    postage
# Name: description, dtype: object

# %% [markdown]
# #### What was the average amount spent per year ?

# %%
# your answer here

average_spend_per_year = orders.groupby('year')['amount_spent'].agg('mean')

print(average_spend_per_year)
# Out:
# year
# 2010    21.892733
# 2011    22.430074
# Name: amount_spent, dtype: float64
