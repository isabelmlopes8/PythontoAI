# %% [markdown]
# # Functions

# %% [markdown]
# On this lab we will put to practice some of the concepts we have learned on this past few days.
#
# `NOTE: On this lab you should try to write all the functions yourself using only the most basic of python syntax and without functions such as len, count, sum, max, min, in, etc. Give it a try. 🧑🏻‍💻👩🏻‍💻`
#
# The cell after each exercise contains a few tests to check if your function works as expected.

# %%
from testing import *
import unittest

# %% [markdown]
# ## 1. Write a function that returns the greater of two numbers

# %%
def greater(a,b):
    if a > b:
        return a
    elif b > a:
        return b
#your code here

# %%
# This will test your function 
test_greater(greater)
# Out:
# ....................................................................................................
# ----------------------------------------------------------------------
# Ran 100 tests in 0.230s
#
# OK

# %%
#your code here
greater(4,8)
# Out:
# 8

# %% [markdown]
# ## 2. Now write a function that returns the largest element on a list

# %%
#your code here


def greatest(list):
    if not list:
        return None

    largest = list[0]
    
    for element in list:
        if element > largest:
            largest = element

    return largest

sample_list = []

largest_element(sample_list)

# %%
# This will test your function 
test_greatest(greatest)
# Out:
# ....................................................................................................
# ----------------------------------------------------------------------
# Ran 100 tests in 0.153s
#
# OK

# %% [markdown]
# ## 3. Write a function that sums all the elements on a list

# %%
def sum_all(lst):
    if not lst:
        return None

    total = 0
    for element in lst:
        total = total + element
    return total
    
#your code here

# %%
# This will test your function 
test_sum(sum_all)
# Out:
# ....................................................................................................
# ----------------------------------------------------------------------
# Ran 100 tests in 0.162s
#
# OK

# %% [markdown]
# ## 4. Write another function that multiplies all the elements on a list

# %%
def mult_all(lst):
    if not lst:
        return None

    total_multiplied = 1
    for element in lst:
       total_multiplied = total_multiplied * element
    return total_multiplied

lista=[ 2,3,4]

mult_all(lista)
    
#your code here
# Out:
# 24

# %%
# This will test your function 
test_mult(mult_all)
# Out:
# ....................................................................................................
# ----------------------------------------------------------------------
# Ran 100 tests in 0.189s
#
# OK

# %% [markdown]
# ## 5. Now combine those two ideas and write a function that receives a list and either "+" or "*" and outputs acordingly

# %%
def oper_all(list, oper):
    if oper == "+":
        return sum_all(list)
    elif oper == "*":
        return mult_all(list)
    else: "Introduce only ""+"" or ""*"" " 


list2 = [3,4,6,7,8,4]

oper_all(list2, "*")
#your code here
# Out:
# 16128

# %%
# This will test your function 
test_operations(oper_all)
# Out:
# ....................................................................................................
# ----------------------------------------------------------------------
# Ran 100 tests in 0.132s
#
# OK

# %% [markdown]
# ## 6. Write a function that returns the factorial of a number.

# %%
def factorial(n):
    if not n:
        return None

    if n<=0:
        return "Introuce a positive number"

    elif n>0:

        total_multiplied = 1
    
        while n>1 :
      
         total_multiplied =  total_multiplied * n
         n=n-1

        return total_multiplied

    
#your code here

# %%
#factorial formula
#n! = n * ( n n =- 1 ) *...*1

# This code defines a function called "factorial" which takes an input "n". The function uses a for loop to iterate through the range of numbers 
# from 1 to n+1. For each number in that range, it multiplies the current value of x by the number in the range. At the end of the loop, 
# the function returns the final value of x, which will be the factorial of the input number "n".

# The Factorial of a positive integer n is the product of all positive integers less than or equal to n. 
# For example, the factorial of 6 (written "6!") is 6 * 5 * 4 * 3 * 2 * 1 = 720.

# So this function takes an input of any positive integer, and returns the factorial of that number.

# %%
# This will test your function 
test_factorial(factorial)
# Out:
# ....................................................................................................
# ----------------------------------------------------------------------
# Ran 100 tests in 0.137s
#
# OK

# %% [markdown]
# ## 7. Write a function that takes a list and returns a list of the unique values.
#
# `NOTE: You cannot use set. 🤔`

# %%
def unique(lst_un):

# Example usage:
    original_list = [1, 2, 2, 3, 4, 4, 5, 5, 5]
    unique_list = unique_values(original_list)
    print(f"The unique values in the list are: {unique_list}")



#your code here


def unique(lst_un):

    unique_values_list = []
    
    for element in lst_un:
        if element not in unique_values_list:
            unique_values_list.append(element)
    
    return unique_values_list

# %%
# This will test your function 
test_unique(unique)
# Out:
# ....................................................................................................
# ----------------------------------------------------------------------
# Ran 100 tests in 0.352s
#
# OK

# %% [markdown]
# ## 8. Write a function that returns the mode of a list, i.e.: the element that appears the most times.
# `NOTE: You should not use count... 🧐`

# %%
#your code here

def mode_counter(lst):
    if not lst:
        return None 

    frequency_dict = {}
    
    for element in lst:
        if element in frequency_dict:
            frequency_dict[element] += 1
        else:
            frequency_dict[element] =1

    mode = None
    max_frequency = 0

    for element, frequency in frequency_dict.items():
            if frequency > max_frequency:
                max_frequency = frequency
                mode = element
    
    return mode

list = (1,1,1,3,5,6,7,7,7,8)

mode_counter(list)
# Out:
# 1

# %%
# This will test your function 
test_mode(mode_counter)
# Out:
# ....................................................................................................
# ----------------------------------------------------------------------
# Ran 100 tests in 0.132s
#
# OK

# %% [markdown]
# ## 9. Write a function that calculates the standard deviation of a list.
# `NOTE: Do not use any libraries or already built functions. 😉`

# %%
def stdev(list_sd):
#your code here


    if not list:
        return None 

    sum_all_elements = 0
    num_elements = 0
    for element in list_sd:
        sum_all_elements += element
        num_elements += 1

    average = sum_all_elements / num_elements
    
    variance_sum = 0
    for element in list_sd:
        variance_sum += (element - average) ** 2

    variance = variance_sum / num_elements

    standard_deviation = variance ** (0.5)

    return standard_deviation
# Out:
# 2.1572527928336

# %%
# This will test your function 
test_stdev(st_dev)
# Out:
# ..F....FFF.F.F.FFF....FF.FF.F.....F.F.FF..F..FF.FF.FFFFF.F.FF...F.FF...FFFF...F.F.FF...F..FFFF.....F
# ======================================================================
# FAIL: runTest (testing.test_stdev.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\isabel.lopes\OneDrive - XPLOR SOLUTIONS\PythonForAISolutions\WEEK2\Functions\testing.py", line 142, in runTest
#     self.assertAlmostEqual(fn(self.input), self.output, delta=5, msg=f"Should be {self.output}")
# AssertionError: 626.170243091552 != 636.8747833406285 within 5 delta (10.704540249076445 difference) : Should be 636.8747833406285
#
# ======================================================================
# FAIL: runTest (testing.test_stdev.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\isabel.lopes\OneDrive - XPLOR SOLUTIONS\PythonForAISolutions\WEEK2\Functions\testing.py", line 142, in runTest
#     self.assertAlmostEqual(fn(self.input), self.output, delta=5, msg=f"Should be {self.output}")
# AssertionError: 541.1151859303567 != 547.2296758965272 within 5 delta (6.114489966170481 difference) : Should be 547.2296758965272
#
# ======================================================================
# FAIL: runTest (testing.test_stdev.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\isabel.lopes\OneDrive - XPLOR SOLUTIONS\PythonForAISolutions\WEEK2\Functions\testing.py", line 142, in runTest
#     self.assertAlmostEqual(fn(self.input), self.output, delta=5, msg=f"Should be {self.output}")
# AssertionError: 606.8870333940041 != 618.9057651644927 within 5 delta (12.018731770488557 difference) : Should be 618.9057651644927
#
# ======================================================================
# FAIL: runTest (testing.test_stdev.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\isabel.lopes\OneDrive - XPLOR SOLUTIONS\PythonForAISolutions\WEEK2\Functions\testing.py", line 142, in runTest
#     self.assertAlmostEqual(fn(self.input), self.output, delta=5, msg=f"Should be {self.output}")
# AssertionError: 559.0717184677942 != 564.5262058612269 within 5 delta (5.454487393432714 difference) : Should be 564.5262058612269
#
# ======================================================================
# FAIL: runTest (testing.test_stdev.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\isabel.lopes\OneDrive - XPLOR SOLUTIONS\PythonForAISolutions\WEEK2\Functions\testing.py", line 142, in runTest
#     self.assertAlmostEqual(fn(self.input), self.output, delta=5, msg=f"Should be {self.output}")
# AssertionError: 590.2147665887671 != 603.4796760186617 within 5 delta (13.264909429894601 difference) : Should be 603.4796760186617
#
# ======================================================================
# FAIL: runTest (testing.test_stdev.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\isabel.lopes\OneDrive - XPLOR SOLUTIONS\PythonForAISolutions\WEEK2\Functions\testing.py", line 142, in runTest
#     self.assertAlmostEqual(fn(self.input), self.output, delta=5, msg=f"Should be {self.output}")
# AssertionError: 705.3657708935834 != 722.7848326339688 within 5 delta (17.41906174038536 difference) : Should be 722.7848326339688
#
# ======================================================================
# FAIL: runTest (testing.test_stdev.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\isabel.lopes\OneDrive - XPLOR SOLUTIONS\PythonForAISolutions\WEEK2\Functions\testing.py", line 142, in runTest
#     self.assertAlmostEqual(fn(self.input), self.output, delta=5, msg=f"Should be {self.output}")
# AssertionError: 645.7079579362088 != 651.6593091630435 within 5 delta (5.951351226834731 difference) : Should be 651.6593091630435
#
# ======================================================================
# FAIL: runTest (testing.test_stdev.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\isabel.lopes\OneDrive - XPLOR SOLUTIONS\PythonForAISolutions\WEEK2\Functions\testing.py", line 142, in runTest
#     self.assertAlmostEqual(fn(self.input), self.output, delta=5, msg=f"Should be {self.output}")
# AssertionError: 559.7475802124063 != 565.7990812735806 within 5 delta (6.0515010611742355 difference) : Should be 565.7990812735806
#
# ======================================================================
# FAIL: runTest (testing.test_stdev.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\isabel.lopes\OneDrive - XPLOR SOLUTIONS\PythonForAISolutions\WEEK2\Functions\testing.py", line 142, in runTest
#     self.assertAlmostEqual(fn(self.input), self.output, delta=5, msg=f"Should be {self.output}")
# AssertionError: 572.211870256822 != 577.4858238672849 within 5 delta (5.273953610462968 difference) : Should be 577.4858238672849
#
# ======================================================================
# FAIL: runTest (testing.test_stdev.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\isabel.lopes\OneDrive - XPLOR SOLUTIONS\PythonForAISolutions\WEEK2\Functions\testing.py", line 142, in runTest
#     self.assertAlmostEqual(fn(self.input), self.output, delta=5, msg=f"Should be {self.output}")
# AssertionError: 566.1718242954508 != 573.771786156225 within 5 delta (7.599961860774101 difference) : Should be 573.771786156225
#
# ======================================================================
# FAIL: runTest (testing.test_stdev.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\isabel.lopes\OneDrive - XPLOR SOLUTIONS\PythonForAISolutions\WEEK2\Functions\testing.py", line 142, in runTest
#     self.assertAlmostEqual(fn(self.input), self.output, delta=5, msg=f"Should be {self.output}")
# AssertionError: 619.3640947050351 != 624.8696615974906 within 5 delta (5.505566892455477 difference) : Should be 624.8696615974906
#
# ======================================================================
# FAIL: runTest (testing.test_stdev.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\isabel.lopes\OneDrive - XPLOR SOLUTIONS\PythonForAISolutions\WEEK2\Functions\testing.py", line 142, in runTest
#     self.assertAlmostEqual(fn(self.input), self.output, delta=5, msg=f"Should be {self.output}")
# AssertionError: 554.7991751649466 != 567.2681292253096 within 5 delta (12.46895406036299 difference) : Should be 567.2681292253096
#
# ======================================================================
# FAIL: runTest (testing.test_stdev.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\isabel.lopes\OneDrive - XPLOR SOLUTIONS\PythonForAISolutions\WEEK2\Functions\testing.py", line 142, in runTest
#     self.assertAlmostEqual(fn(self.input), self.output, delta=5, msg=f"Should be {self.output}")
# AssertionError: 569.9928069721583 != 575.7796843393827 within 5 delta (5.786877367224406 difference) : Should be 575.7796843393827
#
# ======================================================================
# FAIL: runTest (testing.test_stdev.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\isabel.lopes\OneDrive - XPLOR SOLUTIONS\PythonForAISolutions\WEEK2\Functions\testing.py", line 142, in runTest
#     self.assertAlmostEqual(fn(self.input), self.output, delta=5, msg=f"Should be {self.output}")
# AssertionError: 571.3412561901431 != 586.9973400220673 within 5 delta (15.656083831924207 difference) : Should be 586.9973400220673
#
# ======================================================================
# FAIL: runTest (testing.test_stdev.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\isabel.lopes\OneDrive - XPLOR SOLUTIONS\PythonForAISolutions\WEEK2\Functions\testing.py", line 142, in runTest
#     self.assertAlmostEqual(fn(self.input), self.output, delta=5, msg=f"Should be {self.output}")
# AssertionError: 601.8760632011755 != 616.0397907680345 within 5 delta (14.163727566859052 difference) : Should be 616.0397907680345
#
# ======================================================================
# FAIL: runTest (testing.test_stdev.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\isabel.lopes\OneDrive - XPLOR SOLUTIONS\PythonForAISolutions\WEEK2\Functions\testing.py", line 142, in runTest
#     self.assertAlmostEqual(fn(self.input), self.output, delta=5, msg=f"Should be {self.output}")
# AssertionError: 518.2572241657612 != 528.9440644655475 within 5 delta (10.686840299786354 difference) : Should be 528.9440644655475
#
# ======================================================================
# FAIL: runTest (testing.test_stdev.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\isabel.lopes\OneDrive - XPLOR SOLUTIONS\PythonForAISolutions\WEEK2\Functions\testing.py", line 142, in runTest
#     self.assertAlmostEqual(fn(self.input), self.output, delta=5, msg=f"Should be {self.output}")
# AssertionError: 581.3779738302475 != 588.9780084747957 within 5 delta (7.600034644548259 difference) : Should be 588.9780084747957
#
# ======================================================================
# FAIL: runTest (testing.test_stdev.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\isabel.lopes\OneDrive - XPLOR SOLUTIONS\PythonForAISolutions\WEEK2\Functions\testing.py", line 142, in runTest
#     self.assertAlmostEqual(fn(self.input), self.output, delta=5, msg=f"Should be {self.output}")
# AssertionError: 541.1583330345587 != 548.4225283110028 within 5 delta (7.26419527644407 difference) : Should be 548.4225283110028
#
# ======================================================================
# FAIL: runTest (testing.test_stdev.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\isabel.lopes\OneDrive - XPLOR SOLUTIONS\PythonForAISolutions\WEEK2\Functions\testing.py", line 142, in runTest
#     self.assertAlmostEqual(fn(self.input), self.output, delta=5, msg=f"Should be {self.output}")
# AssertionError: 572.5798715834852 != 581.1905783936515 within 5 delta (8.610706810166334 difference) : Should be 581.1905783936515
#
# ======================================================================
# FAIL: runTest (testing.test_stdev.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\isabel.lopes\OneDrive - XPLOR SOLUTIONS\PythonForAISolutions\WEEK2\Functions\testing.py", line 142, in runTest
#     self.assertAlmostEqual(fn(self.input), self.output, delta=5, msg=f"Should be {self.output}")
# AssertionError: 478.41629232325545 != 501.767240497388 within 5 delta (23.350948174132554 difference) : Should be 501.767240497388
#
# ======================================================================
# FAIL: runTest (testing.test_stdev.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\isabel.lopes\OneDrive - XPLOR SOLUTIONS\PythonForAISolutions\WEEK2\Functions\testing.py", line 142, in runTest
#     self.assertAlmostEqual(fn(self.input), self.output, delta=5, msg=f"Should be {self.output}")
# AssertionError: 550.9016834426488 != 558.2966677981677 within 5 delta (7.394984355518886 difference) : Should be 558.2966677981677
#
# ======================================================================
# FAIL: runTest (testing.test_stdev.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\isabel.lopes\OneDrive - XPLOR SOLUTIONS\PythonForAISolutions\WEEK2\Functions\testing.py", line 142, in runTest
#     self.assertAlmostEqual(fn(self.input), self.output, delta=5, msg=f"Should be {self.output}")
# AssertionError: 517.7331205563181 != 529.3690255553222 within 5 delta (11.635904999004083 difference) : Should be 529.3690255553222
#
# ======================================================================
# FAIL: runTest (testing.test_stdev.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\isabel.lopes\OneDrive - XPLOR SOLUTIONS\PythonForAISolutions\WEEK2\Functions\testing.py", line 142, in runTest
#     self.assertAlmostEqual(fn(self.input), self.output, delta=5, msg=f"Should be {self.output}")
# AssertionError: 598.0717158867739 != 607.6414709827371 within 5 delta (9.569755095963274 difference) : Should be 607.6414709827371
#
# ======================================================================
# FAIL: runTest (testing.test_stdev.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\isabel.lopes\OneDrive - XPLOR SOLUTIONS\PythonForAISolutions\WEEK2\Functions\testing.py", line 142, in runTest
#     self.assertAlmostEqual(fn(self.input), self.output, delta=5, msg=f"Should be {self.output}")
# AssertionError: 424.7882514780158 != 438.71941963704626 within 5 delta (13.931168159030449 difference) : Should be 438.71941963704626
#
# ======================================================================
# FAIL: runTest (testing.test_stdev.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\isabel.lopes\OneDrive - XPLOR SOLUTIONS\PythonForAISolutions\WEEK2\Functions\testing.py", line 142, in runTest
#     self.assertAlmostEqual(fn(self.input), self.output, delta=5, msg=f"Should be {self.output}")
# AssertionError: 503.9088497860834 != 511.4868517031896 within 5 delta (7.578001917106178 difference) : Should be 511.4868517031896
#
# ======================================================================
# FAIL: runTest (testing.test_stdev.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\isabel.lopes\OneDrive - XPLOR SOLUTIONS\PythonForAISolutions\WEEK2\Functions\testing.py", line 142, in runTest
#     self.assertAlmostEqual(fn(self.input), self.output, delta=5, msg=f"Should be {self.output}")
# AssertionError: 566.4760113443211 != 571.6025955790677 within 5 delta (5.126584234746588 difference) : Should be 571.6025955790677
#
# ======================================================================
# FAIL: runTest (testing.test_stdev.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\isabel.lopes\OneDrive - XPLOR SOLUTIONS\PythonForAISolutions\WEEK2\Functions\testing.py", line 142, in runTest
#     self.assertAlmostEqual(fn(self.input), self.output, delta=5, msg=f"Should be {self.output}")
# AssertionError: 617.0321990394057 != 627.2317693429744 within 5 delta (10.199570303568748 difference) : Should be 627.2317693429744
#
# ======================================================================
# FAIL: runTest (testing.test_stdev.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\isabel.lopes\OneDrive - XPLOR SOLUTIONS\PythonForAISolutions\WEEK2\Functions\testing.py", line 142, in runTest
#     self.assertAlmostEqual(fn(self.input), self.output, delta=5, msg=f"Should be {self.output}")
# AssertionError: 552.1294138152757 != 563.5147232622528 within 5 delta (11.38530944697709 difference) : Should be 563.5147232622528
#
# ======================================================================
# FAIL: runTest (testing.test_stdev.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\isabel.lopes\OneDrive - XPLOR SOLUTIONS\PythonForAISolutions\WEEK2\Functions\testing.py", line 142, in runTest
#     self.assertAlmostEqual(fn(self.input), self.output, delta=5, msg=f"Should be {self.output}")
# AssertionError: 640.4992559519488 != 650.7478947954002 within 5 delta (10.248638843451317 difference) : Should be 650.7478947954002
#
# ======================================================================
# FAIL: runTest (testing.test_stdev.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\isabel.lopes\OneDrive - XPLOR SOLUTIONS\PythonForAISolutions\WEEK2\Functions\testing.py", line 142, in runTest
#     self.assertAlmostEqual(fn(self.input), self.output, delta=5, msg=f"Should be {self.output}")
# AssertionError: 582.8219027249164 != 587.824757598573 within 5 delta (5.002854873656588 difference) : Should be 587.824757598573
#
# ======================================================================
# FAIL: runTest (testing.test_stdev.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\isabel.lopes\OneDrive - XPLOR SOLUTIONS\PythonForAISolutions\WEEK2\Functions\testing.py", line 142, in runTest
#     self.assertAlmostEqual(fn(self.input), self.output, delta=5, msg=f"Should be {self.output}")
# AssertionError: 475.76403762908967 != 487.51306697994306 within 5 delta (11.749029350853391 difference) : Should be 487.51306697994306
#
# ======================================================================
# FAIL: runTest (testing.test_stdev.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\isabel.lopes\OneDrive - XPLOR SOLUTIONS\PythonForAISolutions\WEEK2\Functions\testing.py", line 142, in runTest
#     self.assertAlmostEqual(fn(self.input), self.output, delta=5, msg=f"Should be {self.output}")
# AssertionError: 588.152292838924 != 595.4588126486799 within 5 delta (7.306519809755855 difference) : Should be 595.4588126486799
#
# ======================================================================
# FAIL: runTest (testing.test_stdev.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\isabel.lopes\OneDrive - XPLOR SOLUTIONS\PythonForAISolutions\WEEK2\Functions\testing.py", line 142, in runTest
#     self.assertAlmostEqual(fn(self.input), self.output, delta=5, msg=f"Should be {self.output}")
# AssertionError: 601.4950061626142 != 608.1415615933498 within 5 delta (6.646555430735589 difference) : Should be 608.1415615933498
#
# ======================================================================
# FAIL: runTest (testing.test_stdev.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\isabel.lopes\OneDrive - XPLOR SOLUTIONS\PythonForAISolutions\WEEK2\Functions\testing.py", line 142, in runTest
#     self.assertAlmostEqual(fn(self.input), self.output, delta=5, msg=f"Should be {self.output}")
# AssertionError: 584.9190456213198 != 597.4993890603874 within 5 delta (12.580343439067633 difference) : Should be 597.4993890603874
#
# ======================================================================
# FAIL: runTest (testing.test_stdev.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\isabel.lopes\OneDrive - XPLOR SOLUTIONS\PythonForAISolutions\WEEK2\Functions\testing.py", line 142, in runTest
#     self.assertAlmostEqual(fn(self.input), self.output, delta=5, msg=f"Should be {self.output}")
# AssertionError: 585.3836734862908 != 595.7452508756462 within 5 delta (10.361577389355375 difference) : Should be 595.7452508756462
#
# ======================================================================
# FAIL: runTest (testing.test_stdev.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\isabel.lopes\OneDrive - XPLOR SOLUTIONS\PythonForAISolutions\WEEK2\Functions\testing.py", line 142, in runTest
#     self.assertAlmostEqual(fn(self.input), self.output, delta=5, msg=f"Should be {self.output}")
# AssertionError: 615.6111759869211 != 628.3055254677722 within 5 delta (12.694349480851088 difference) : Should be 628.3055254677722
#
# ======================================================================
# FAIL: runTest (testing.test_stdev.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\isabel.lopes\OneDrive - XPLOR SOLUTIONS\PythonForAISolutions\WEEK2\Functions\testing.py", line 142, in runTest
#     self.assertAlmostEqual(fn(self.input), self.output, delta=5, msg=f"Should be {self.output}")
# AssertionError: 603.7820292861395 != 608.8773266184712 within 5 delta (5.095297332331711 difference) : Should be 608.8773266184712
#
# ======================================================================
# FAIL: runTest (testing.test_stdev.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\isabel.lopes\OneDrive - XPLOR SOLUTIONS\PythonForAISolutions\WEEK2\Functions\testing.py", line 142, in runTest
#     self.assertAlmostEqual(fn(self.input), self.output, delta=5, msg=f"Should be {self.output}")
# AssertionError: 595.277547052374 != 600.8671302177385 within 5 delta (5.589583165364502 difference) : Should be 600.8671302177385
#
# ======================================================================
# FAIL: runTest (testing.test_stdev.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\isabel.lopes\OneDrive - XPLOR SOLUTIONS\PythonForAISolutions\WEEK2\Functions\testing.py", line 142, in runTest
#     self.assertAlmostEqual(fn(self.input), self.output, delta=5, msg=f"Should be {self.output}")
# AssertionError: 421.4451282121434 != 435.2666567749016 within 5 delta (13.821528562758203 difference) : Should be 435.2666567749016
#
# ======================================================================
# FAIL: runTest (testing.test_stdev.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\isabel.lopes\OneDrive - XPLOR SOLUTIONS\PythonForAISolutions\WEEK2\Functions\testing.py", line 142, in runTest
#     self.assertAlmostEqual(fn(self.input), self.output, delta=5, msg=f"Should be {self.output}")
# AssertionError: 571.1681213558628 != 578.835150607621 within 5 delta (7.667029251758208 difference) : Should be 578.835150607621
#
# ======================================================================
# FAIL: runTest (testing.test_stdev.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\isabel.lopes\OneDrive - XPLOR SOLUTIONS\PythonForAISolutions\WEEK2\Functions\testing.py", line 142, in runTest
#     self.assertAlmostEqual(fn(self.input), self.output, delta=5, msg=f"Should be {self.output}")
# AssertionError: 539.400259547583 != 568.5777968854492 within 5 delta (29.17753733786617 difference) : Should be 568.5777968854492
#
# ======================================================================
# FAIL: runTest (testing.test_stdev.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\isabel.lopes\OneDrive - XPLOR SOLUTIONS\PythonForAISolutions\WEEK2\Functions\testing.py", line 142, in runTest
#     self.assertAlmostEqual(fn(self.input), self.output, delta=5, msg=f"Should be {self.output}")
# AssertionError: 611.0571386267136 != 617.9619582289688 within 5 delta (6.904819602255202 difference) : Should be 617.9619582289688
#
# ======================================================================
# FAIL: runTest (testing.test_stdev.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\isabel.lopes\OneDrive - XPLOR SOLUTIONS\PythonForAISolutions\WEEK2\Functions\testing.py", line 142, in runTest
#     self.assertAlmostEqual(fn(self.input), self.output, delta=5, msg=f"Should be {self.output}")
# AssertionError: 631.0751811769503 != 661.877233878967 within 5 delta (30.80205270201668 difference) : Should be 661.877233878967
#
# ======================================================================
# FAIL: runTest (testing.test_stdev.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\isabel.lopes\OneDrive - XPLOR SOLUTIONS\PythonForAISolutions\WEEK2\Functions\testing.py", line 142, in runTest
#     self.assertAlmostEqual(fn(self.input), self.output, delta=5, msg=f"Should be {self.output}")
# AssertionError: 617.0041247836193 != 623.2682866493827 within 5 delta (6.264161865763413 difference) : Should be 623.2682866493827
#
# ======================================================================
# FAIL: runTest (testing.test_stdev.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\isabel.lopes\OneDrive - XPLOR SOLUTIONS\PythonForAISolutions\WEEK2\Functions\testing.py", line 142, in runTest
#     self.assertAlmostEqual(fn(self.input), self.output, delta=5, msg=f"Should be {self.output}")
# AssertionError: 572.5536819957592 != 579.3297010744964 within 5 delta (6.776019078737136 difference) : Should be 579.3297010744964
#
# ======================================================================
# FAIL: runTest (testing.test_stdev.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\isabel.lopes\OneDrive - XPLOR SOLUTIONS\PythonForAISolutions\WEEK2\Functions\testing.py", line 142, in runTest
#     self.assertAlmostEqual(fn(self.input), self.output, delta=5, msg=f"Should be {self.output}")
# AssertionError: 490.718463072259 != 517.2626777351888 within 5 delta (26.544214662929846 difference) : Should be 517.2626777351888
#
# ======================================================================
# FAIL: runTest (testing.test_stdev.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\isabel.lopes\OneDrive - XPLOR SOLUTIONS\PythonForAISolutions\WEEK2\Functions\testing.py", line 142, in runTest
#     self.assertAlmostEqual(fn(self.input), self.output, delta=5, msg=f"Should be {self.output}")
# AssertionError: 497.3850911405457 != 514.8424816896727 within 5 delta (17.457390549127012 difference) : Should be 514.8424816896727
#
# ======================================================================
# FAIL: runTest (testing.test_stdev.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\isabel.lopes\OneDrive - XPLOR SOLUTIONS\PythonForAISolutions\WEEK2\Functions\testing.py", line 142, in runTest
#     self.assertAlmostEqual(fn(self.input), self.output, delta=5, msg=f"Should be {self.output}")
# AssertionError: 637.263483576456 != 653.818538723817 within 5 delta (16.55505514736103 difference) : Should be 653.818538723817
#
# ----------------------------------------------------------------------
# Ran 100 tests in 0.252s
#
# FAILED (failures=48)

# %% [raw]
# ## 10. Write a function to check if a string is a pangram, i.e.: if it contains all the letters of the alphabet at least once. Mind that the strings may contain characters that are not letters.

# %%
#your code here
def pangram(string):
    alphabet_set = set('abcdefghijklmnopqrstuvwxyz')
    string = string.lower()
    letters_found = set()

    for char in string:
       
        if 'a' <= char <= 'z':
            letters_found.add(char)

    return alphabet_set.issubset(letters_found)

# %%
# This will test your function 
test_pangram(pangram)
# Out:
# ..............................
# ----------------------------------------------------------------------
# Ran 30 tests in 0.091s
#
# OK

# %% [markdown]
# ## 11. Write a function that receives a string of comma separated words and returns a string of comma separated words sorted alphabetically.
#
# `NOTE: You may use sorted but not split and definitely no join! 🤪`

# %%
def alpha(string: str) -> str:
#your code here
    if not string:
        return None

    
        
    
    words = []
    word = ""
    for char in string:

    
        if char == ',':
            words.append(word.strip())
            word = ""
        else:
            word = char
        words.append(word.strip())  # Append the last word after the last comma
    
    # Sort the list of words alphabetically using sort()
    words.sort()

   
    # Construct the sorted string manually
    sorted_string = ""
    for idx in range(len(words)):
        sorted_string += words[idx]
        if idx != len(words) - 1:
            sorted_string += ", "

    return sorted_string


test = ("zebra","horse","dog","cat","sheep")
alpha(test)
# Out:
# 'cat, dog, horse, sheep, zebra'

# %%
# This will test your function 
test_alpha(sort_alpha)
# Out:
# FFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFF
# ======================================================================
# FAIL: runTest (testing.test_alpha.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\isabel.lopes\OneDrive - XPLOR SOLUTIONS\PythonForAISolutions\WEEK2\Functions\testing.py", line 187, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: ', , , , , , , , , , , , , , , , a, a, a, [336 chars]z, z' != 'aoud,bahw,ckutdrx,cmzc,czjgx,dlba,hayh,hq[72 chars]ztbx'
# - , , , , , , , , , , , , , , , , a, a, a, a, a, a, a, a, a, b, b, b, b, b, b, c, c, c, c, c, c, c, d, d, d, d, d, d, d, e, e, e, e, e, f, f, f, g, g, g, h, h, h, h, h, h, h, i, j, j, j, j, k, k, k, k, k, k, k, k, l, m, m, m, m, o, o, o, o, o, p, p, p, q, q, r, r, r, r, s, s, s, s, s, t, t, t, t, t, t, t, u, u, u, u, u, v, v, w, w, w, x, x, x, x, x, x, x, x, y, y, z, z, z, z, z, z
# + aoud,bahw,ckutdrx,cmzc,czjgx,dlba,hayh,hqmksc,joke,ktprjkx,tpysdrrpk,tsaghgmud,uaef,vqaujxt,wasihezesb,zbmvkzofo,ztbx
#  : Should be aoud,bahw,ckutdrx,cmzc,czjgx,dlba,hayh,hqmksc,joke,ktprjkx,tpysdrrpk,tsaghgmud,uaef,vqaujxt,wasihezesb,zbmvkzofo,ztbx
#
# ======================================================================
# FAIL: runTest (testing.test_alpha.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\isabel.lopes\OneDrive - XPLOR SOLUTIONS\PythonForAISolutions\WEEK2\Functions\testing.py", line 187, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: ', , , , c, d, d, d, e, f, f, h, h, h, l, [63 chars]y, y' != 'dxocdtonnl,fydsxxq,neso,tpfhr,wvyh'
# - , , , , c, d, d, d, e, f, f, h, h, h, l, l, n, n, n, o, o, o, o, p, q, r, r, s, s, t, t, v, w, x, x, x, y, y
# + dxocdtonnl,fydsxxq,neso,tpfhr,wvyh
#  : Should be dxocdtonnl,fydsxxq,neso,tpfhr,wvyh
#
# ======================================================================
# FAIL: runTest (testing.test_alpha.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\isabel.lopes\OneDrive - XPLOR SOLUTIONS\PythonForAISolutions\WEEK2\Functions\testing.py", line 187, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: ', , , , , , a, b, b, b, d, e, e, e, f, f,[118 chars]z, z' != 'drpay,gqefx,hgtkfq,hrkbne,jboorzbsfn,mzktfnrf,unmvr'
# - , , , , , , a, b, b, b, d, e, e, e, f, f, f, f, f, f, g, g, h, h, j, k, k, k, m, m, n, n, n, n, n, o, o, p, q, q, q, r, r, r, r, r, r, s, t, t, u, v, x, x, y, z, z
# + drpay,gqefx,hgtkfq,hrkbne,jboorzbsfn,mzktfnrf,unmvr
#  : Should be drpay,gqefx,hgtkfq,hrkbne,jboorzbsfn,mzktfnrf,unmvr
#
# ======================================================================
# FAIL: runTest (testing.test_alpha.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\isabel.lopes\OneDrive - XPLOR SOLUTIONS\PythonForAISolutions\WEEK2\Functions\testing.py", line 187, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: ', , , , , , , , , , , , , , , , , , , a, [489 chars]z, z' != 'dfgvckhq,esxefpxhc,fhriihvcib,fxutug,gukk[121 chars]puyu'
# Diff is 707 characters long. Set self.maxDiff to None to see it. : Should be dfgvckhq,esxefpxhc,fhriihvcib,fxutug,gukk,hrincqpx,jbhyyf,jomkbm,jtqzaozwj,kcggcn,lcsutgioc,nvnluli,olsspgdlov,qqxnw,rfdikv,siyolaxrcj,taul,wccqvtzx,wenvxdbzmu,xapuyu
#
# ======================================================================
# FAIL: runTest (testing.test_alpha.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\isabel.lopes\OneDrive - XPLOR SOLUTIONS\PythonForAISolutions\WEEK2\Functions\testing.py", line 187, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: ', , , , , , , , , a, a, b, b, b, c, c, c,[193 chars]z, z' != 'cflgb,gcwp,hqshrg,jccx,mbckcruw,rwvcphmiq[29 chars]zdpx'
# - , , , , , , , , , a, a, b, b, b, c, c, c, c, c, c, c, c, d, d, d, e, f, f, g, g, g, g, h, h, h, i, i, i, j, k, l, m, m, m, m, m, m, n, n, n, p, p, p, p, q, q, q, q, q, q, r, r, r, r, r, s, t, u, v, v, w, w, w, w, w, x, x, x, x, y, y, z, z
# + cflgb,gcwp,hqshrg,jccx,mbckcruw,rwvcphmiq,tvmm,yirewqfdqn,ynriqxda,zcmzdpx
#  : Should be cflgb,gcwp,hqshrg,jccx,mbckcruw,rwvcphmiq,tvmm,yirewqfdqn,ynriqxda,zcmzdpx
#
# ======================================================================
# FAIL: runTest (testing.test_alpha.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\isabel.lopes\OneDrive - XPLOR SOLUTIONS\PythonForAISolutions\WEEK2\Functions\testing.py", line 187, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: ', , , , , , , , a, a, a, b, b, b, b, b, c[182 chars]z, z' != 'adxgradn,csbe,fzzfachm,ibcxbbygv,jbqtnhnp[26 chars]jiwd'
# - , , , , , , , , a, a, a, b, b, b, b, b, c, c, c, c, d, d, d, d, d, d, e, e, e, e, f, f, g, g, g, h, h, h, h, i, i, i, j, j, j, j, l, m, m, m, n, n, n, n, n, p, p, q, q, q, q, r, r, s, t, u, v, v, v, v, w, x, x, x, x, y, y, z, z
# + adxgradn,csbe,fzzfachm,ibcxbbygv,jbqtnhnpih,mejcqgrq,nldujx,pvyde,vjiwd
#  : Should be adxgradn,csbe,fzzfachm,ibcxbbygv,jbqtnhnpih,mejcqgrq,nldujx,pvyde,vjiwd
#
# ======================================================================
# FAIL: runTest (testing.test_alpha.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\isabel.lopes\OneDrive - XPLOR SOLUTIONS\PythonForAISolutions\WEEK2\Functions\testing.py", line 187, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: ', , , , , , , , a, a, a, c, c, c, c, c, d[170 chars]z, z' != 'akow,cpgwdiu,csakwlvuzd,ehrwvvc,jysuuxkc,[22 chars]hmly'
# - , , , , , , , , a, a, a, c, c, c, c, c, d, d, d, e, e, e, g, g, h, h, h, h, h, h, h, i, j, k, k, k, k, l, l, m, o, p, p, p, p, r, r, s, s, s, t, u, u, u, u, u, u, u, v, v, v, w, w, w, w, w, w, x, x, y, y, y, z, z, z
# + akow,cpgwdiu,csakwlvuzd,ehrwvvc,jysuuxkc,ppah,skpehrz,utwgeh,uxhmly
#  : Should be akow,cpgwdiu,csakwlvuzd,ehrwvvc,jysuuxkc,ppah,skpehrz,utwgeh,uxhmly
#
# ======================================================================
# FAIL: runTest (testing.test_alpha.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\isabel.lopes\OneDrive - XPLOR SOLUTIONS\PythonForAISolutions\WEEK2\Functions\testing.py", line 187, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: ', , , , , , , , , , , , , , , , , a, a, a[410 chars]z, z' != 'dlvy,gejqkzyg,glomlecq,ifkyzxl,jlzzsgcrbb[96 chars]yxoz'
# - , , , , , , , , , , , , , , , , , a, a, a, a, b, b, b, b, c, c, c, d, d, d, d, d, d, e, e, e, e, e, e, e, f, f, f, g, g, g, g, g, h, h, i, j, j, j, j, k, k, k, k, k, k, l, l, l, l, l, l, l, l, l, l, l, l, m, m, m, m, m, m, m, m, n, n, n, o, o, o, o, o, p, p, q, q, q, q, q, q, r, r, r, r, r, r, r, r, r, s, s, s, s, t, t, t, u, u, u, u, u, u, u, u, v, v, v, w, w, w, w, w, w, w, x, x, x, x, y, y, y, y, y, y, y, y, y, z, z, z, z, z, z, z, z, z, z, z, z, z
# + dlvy,gejqkzyg,glomlecq,ifkyzxl,jlzzsgcrbb,kezvmtea,ldwo,mbdhvxz,nwfwer,pumrs,qtadkqu,spul,ulzkxnwad,wkbwj,yonmwhyytr,yqml,zermzrfmcu,zeuryxoz
#  : Should be dlvy,gejqkzyg,glomlecq,ifkyzxl,jlzzsgcrbb,kezvmtea,ldwo,mbdhvxz,nwfwer,pumrs,qtadkqu,spul,ulzkxnwad,wkbwj,yonmwhyytr,yqml,zermzrfmcu,zeuryxoz
#
# ======================================================================
# FAIL: runTest (testing.test_alpha.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\isabel.lopes\OneDrive - XPLOR SOLUTIONS\PythonForAISolutions\WEEK2\Functions\testing.py", line 187, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: ', , , b, b, c, c, h, i, j, j, j, k, n, o,[52 chars]y, z' != 'jqijtupv,nkyosv,ochcjbbz,xystuo'
# - , , , b, b, c, c, h, i, j, j, j, k, n, o, o, o, o, p, q, s, s, t, t, u, u, v, v, v, v, x, y, y, z
# + jqijtupv,nkyosv,ochcjbbz,xystuo
#  : Should be jqijtupv,nkyosv,ochcjbbz,xystuo
#
# ======================================================================
# FAIL: runTest (testing.test_alpha.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\isabel.lopes\OneDrive - XPLOR SOLUTIONS\PythonForAISolutions\WEEK2\Functions\testing.py", line 187, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: ', , , , , , , , , , , , , , , , , , a, a,[442 chars]z, z' != 'anlg,bubh,duxsvhjbnz,edmwz,ekyjsxietw,eov[106 chars]bnte'
# Diff is 645 characters long. Set self.maxDiff to None to see it. : Should be anlg,bubh,duxsvhjbnz,edmwz,ekyjsxietw,eovmdbb,gclauqkg,gxuvhabxiq,iizobw,jssh,kgvvflonn,nknbxbz,oqctr,shoqskix,teghbhxx,tooeotz,wfxjxua,xinmdvwn,xjbnte
#
# ======================================================================
# FAIL: runTest (testing.test_alpha.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\isabel.lopes\OneDrive - XPLOR SOLUTIONS\PythonForAISolutions\WEEK2\Functions\testing.py", line 187, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: ', , , , , , b, b, b, c, c, d, d, e, e, e,[148 chars]z, z' != 'bodmqoe,fibfovtrd,jqusnicno,jznqzjybs,nce[16 chars]xnif'
# - , , , , , , b, b, b, c, c, d, d, e, e, e, f, f, f, f, h, h, i, i, i, i, i, j, j, j, k, k, l, m, n, n, n, n, n, o, o, o, o, o, q, q, q, q, r, r, s, s, s, t, t, u, v, v, v, w, x, x, y, y, y, z, z
# + bodmqoe,fibfovtrd,jqusnicno,jznqzjybs,ncewv,tklqhrkhi,yxyxnif
#  : Should be bodmqoe,fibfovtrd,jqusnicno,jznqzjybs,ncewv,tklqhrkhi,yxyxnif
#
# ======================================================================
# FAIL: runTest (testing.test_alpha.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\isabel.lopes\OneDrive - XPLOR SOLUTIONS\PythonForAISolutions\WEEK2\Functions\testing.py", line 187, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: ', , , , , , , , , , , , , , , , , , a, a,[418 chars]z, z' != 'ahvomyxpxp,airoit,hkiem,humuebko,hyvifw,j[98 chars]umnj'
# - , , , , , , , , , , , , , , , , , , a, a, a, a, a, a, a, a, b, b, b, c, c, c, c, d, d, d, d, e, e, e, e, e, e, e, f, g, g, g, g, h, h, h, h, h, h, h, i, i, i, i, i, i, j, j, j, j, k, k, k, k, k, l, l, l, l, l, l, l, m, m, m, m, m, m, m, m, n, n, n, n, n, n, n, n, o, o, o, o, o, o, o, o, o, o, o, p, p, p, p, p, p, r, r, s, s, t, t, t, t, t, t, t, t, t, u, u, u, u, u, u, u, u, v, v, v, v, v, v, v, w, w, w, w, w, x, x, x, x, x, x, x, x, x, y, y, y, z, z, z, z, z
# + ahvomyxpxp,airoit,hkiem,humuebko,hyvifw,jszv,kggu,mboz,mlmedsrzot,onnapnlt,pdjhghlee,uowa,vohnnuc,wolx,wyenlka,xcbk,xvallit,xxxtoupd,zincgvumnj
#  : Should be ahvomyxpxp,airoit,hkiem,humuebko,hyvifw,jszv,kggu,mboz,mlmedsrzot,onnapnlt,pdjhghlee,uowa,vohnnuc,wolx,wyenlka,xcbk,xvallit,xxxtoupd,zincgvumnj
#
# ======================================================================
# FAIL: runTest (testing.test_alpha.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\isabel.lopes\OneDrive - XPLOR SOLUTIONS\PythonForAISolutions\WEEK2\Functions\testing.py", line 187, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: ', , , , , , , , a, a, b, b, b, b, c, c, c[200 chars]z, z' != 'afqonnj,ckelexqdmf,kgzvsfzp,lthjukc,mjbdg[32 chars]bbhn'
# - , , , , , , , , a, a, b, b, b, b, c, c, c, d, d, e, e, f, f, f, f, f, f, f, g, g, h, h, i, j, j, j, j, k, k, k, l, l, m, m, m, m, m, n, n, n, n, n, o, o, o, o, o, o, p, p, p, p, q, q, s, s, s, t, t, t, t, u, u, u, u, u, v, w, x, x, x, x, z, z, z
# + afqonnj,ckelexqdmf,kgzvsfzp,lthjukc,mjbdgozu,moimupnf,owmoft,pxspasx,tubobbhn
#  : Should be afqonnj,ckelexqdmf,kgzvsfzp,lthjukc,mjbdgozu,moimupnf,owmoft,pxspasx,tubobbhn
#
# ======================================================================
# FAIL: runTest (testing.test_alpha.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\isabel.lopes\OneDrive - XPLOR SOLUTIONS\PythonForAISolutions\WEEK2\Functions\testing.py", line 187, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: ', , , , , , , , , , , , , , , , , a, a, a[395 chars]z, z' != 'anraanopm,ayuddldx,azdfxxa,behij,egwhpukm[91 chars]eihc'
# - , , , , , , , , , , , , , , , , , a, a, a, a, a, a, a, b, b, c, c, c, c, c, d, d, d, d, d, d, d, e, e, e, e, e, f, f, f, f, f, f, f, f, g, g, g, g, g, h, h, h, h, h, h, h, h, h, h, h, i, i, i, i, i, j, j, j, j, j, j, k, k, k, l, m, m, m, m, m, n, n, n, n, n, o, o, o, p, p, p, p, q, q, q, q, r, r, r, s, s, s, t, u, u, u, u, u, u, u, u, u, u, u, v, v, v, v, w, w, w, w, x, x, x, x, x, x, x, x, y, y, y, y, y, y, y, z, z, z, z, z, z, z, z, z
# + anraanopm,ayuddldx,azdfxxa,behij,egwhpukmmh,hpuf,ifnz,ihxkecu,rucezwdgs,ukqrjsqjy,vfvmf,vngywhhfq,wupj,ydcyx,zbdh,zgzto,zqixnvgu,zuyeihc
#  : Should be anraanopm,ayuddldx,azdfxxa,behij,egwhpukmmh,hpuf,ifnz,ihxkecu,rucezwdgs,ukqrjsqjy,vfvmf,vngywhhfq,wupj,ydcyx,zbdh,zgzto,zqixnvgu,zuyeihc
#
# ======================================================================
# FAIL: runTest (testing.test_alpha.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\isabel.lopes\OneDrive - XPLOR SOLUTIONS\PythonForAISolutions\WEEK2\Functions\testing.py", line 187, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: ', , , a, b, c, d, d, e, e, f, f, g, h, j,[46 chars]y, z' != 'bncnhxqy,eedganxzvm,omdf,unjl'
# - , , , a, b, c, d, d, e, e, f, f, g, h, j, l, m, m, m, n, n, n, n, o, q, u, v, x, x, y, y, z
# + bncnhxqy,eedganxzvm,omdf,unjl
#  : Should be bncnhxqy,eedganxzvm,omdf,unjl
#
# ======================================================================
# FAIL: runTest (testing.test_alpha.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\isabel.lopes\OneDrive - XPLOR SOLUTIONS\PythonForAISolutions\WEEK2\Functions\testing.py", line 187, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: ', , , , , , , , , , , , , , , , , , , , ,[555 chars]z, z' != 'azlyjmo,bhbnwjxyhd,bjvffgw,bouhrzcqzi,ccd[141 chars]pmvz'
# Diff is 793 characters long. Set self.maxDiff to None to see it. : Should be azlyjmo,bhbnwjxyhd,bjvffgw,bouhrzcqzi,ccdce,cdzb,cwjamxdnxl,dykh,edky,eftbngji,hfhklbowtu,jawxxbl,jmlxwe,noint,pljxnk,ryjgthoaa,soge,srqc,trmdaucxzk,uqbpueypcr,vlifbdjp,xbfexumk,yswmpmvz
#
# ======================================================================
# FAIL: runTest (testing.test_alpha.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\isabel.lopes\OneDrive - XPLOR SOLUTIONS\PythonForAISolutions\WEEK2\Functions\testing.py", line 187, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: ', , , , , , , , , , , , , , , , , , , , ,[548 chars]z, z' != 'alehciqli,depa,ecgxk,erlgauy,evgr,gqcmkur[138 chars]zptj'
# Diff is 783 characters long. Set self.maxDiff to None to see it. : Should be alehciqli,depa,ecgxk,erlgauy,evgr,gqcmkurjkk,jcdfkcvljz,khahsejd,ktnglsjk,ltzmlglyx,mvlaeozzsb,otsn,qrohh,qzku,sbcexc,tahpnv,uaarzr,ubert,vtwrf,vykmfqswoj,xeprm,xjnsuu,yvdfdkivih,zptj
#
# ======================================================================
# FAIL: runTest (testing.test_alpha.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\isabel.lopes\OneDrive - XPLOR SOLUTIONS\PythonForAISolutions\WEEK2\Functions\testing.py", line 187, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: ', , , , , , , a, a, a, b, b, b, c, c, d, [159 chars]z, z' != 'aitrib,dezhgzymac,doyfx,evnv,ifsos,vblhvi[19 chars]fiep'
# - , , , , , , , a, a, a, b, b, b, c, c, d, d, d, e, e, e, f, f, f, g, h, h, h, h, h, i, i, i, i, i, j, k, l, l, l, l, l, m, n, o, o, o, p, p, q, r, s, s, s, t, v, v, v, v, v, v, v, w, x, x, x, y, y, y, z, z
# + aitrib,dezhgzymac,doyfx,evnv,ifsos,vblhviqakl,vdhloyh,xpwvljfiep
#  : Should be aitrib,dezhgzymac,doyfx,evnv,ifsos,vblhviqakl,vdhloyh,xpwvljfiep
#
# ======================================================================
# FAIL: runTest (testing.test_alpha.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\isabel.lopes\OneDrive - XPLOR SOLUTIONS\PythonForAISolutions\WEEK2\Functions\testing.py", line 187, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: ', , , , a, a, a, b, b, c, e, e, h, l, l, [54 chars]x, y' != 'eqva,nnse,upahsl,xovwrb,yxtncpp'
# - , , , , a, a, a, b, b, c, e, e, h, l, l, n, n, n, o, p, p, p, p, q, r, s, s, t, u, v, v, w, x, x, y
# + eqva,nnse,upahsl,xovwrb,yxtncpp
#  : Should be eqva,nnse,upahsl,xovwrb,yxtncpp
#
# ======================================================================
# FAIL: runTest (testing.test_alpha.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\isabel.lopes\OneDrive - XPLOR SOLUTIONS\PythonForAISolutions\WEEK2\Functions\testing.py", line 187, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: ', , , , , , , , , , , , , , , , , , , , ,[595 chars]z, z' != 'aoujmtiaj,esuxk,eulcxxkuhk,ftca,glfede,ib[153 chars]gitq'
# Diff is 845 characters long. Set self.maxDiff to None to see it. : Should be aoujmtiaj,esuxk,eulcxxkuhk,ftca,glfede,ibiniwck,kuspoiw,lqmppqogg,lxdtthk,mmri,muqxoonlk,puzgjkfit,recxlxknj,rhmh,rjnyrak,scuvz,szrc,tcumlbyp,thxmxt,uabje,vgftqdmg,wqbmfzm,xwhy,zbukuuelpx,ztlflfgitq
#
# ======================================================================
# FAIL: runTest (testing.test_alpha.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\isabel.lopes\OneDrive - XPLOR SOLUTIONS\PythonForAISolutions\WEEK2\Functions\testing.py", line 187, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: ', , , , , , , , , , , , , , , , a, a, a, [345 chars]z, z' != 'aozs,btnmsljec,cqhcg,dlwh,ghqaf,ixcohwov,[75 chars]yply'
# - , , , , , , , , , , , , , , , , a, a, a, a, a, b, b, b, c, c, c, c, c, c, c, c, d, d, d, e, f, f, f, f, f, g, g, g, g, g, g, g, h, h, h, h, h, h, i, i, j, j, j, j, j, j, j, j, k, l, l, l, l, m, m, m, n, n, n, n, n, n, n, o, o, o, o, p, p, p, p, p, q, q, q, q, q, q, q, q, q, q, q, r, r, r, s, s, s, s, s, t, t, t, u, u, u, u, v, v, v, w, w, w, w, x, x, x, x, x, y, y, y, y, z, z, z, z, z, z
# + aozs,btnmsljec,cqhcg,dlwh,ghqaf,ixcohwov,ksmffcnzhu,lorq,pxypg,rjqz,tjrgq,tqfqjjsa,uvqd,wingnupvbc,wqjpazjx,xbnjmn,zyply
#  : Should be aozs,btnmsljec,cqhcg,dlwh,ghqaf,ixcohwov,ksmffcnzhu,lorq,pxypg,rjqz,tjrgq,tqfqjjsa,uvqd,wingnupvbc,wqjpazjx,xbnjmn,zyply
#
# ======================================================================
# FAIL: runTest (testing.test_alpha.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\isabel.lopes\OneDrive - XPLOR SOLUTIONS\PythonForAISolutions\WEEK2\Functions\testing.py", line 187, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: ', , , , , , , , , , , , , , , , , a, a, a[416 chars]z, z' != 'bausx,exgdx,exrigt,fdrzycftr,fvbtrr,mkcbf[98 chars]kust'
# - , , , , , , , , , , , , , , , , , a, a, a, a, b, b, b, c, c, c, c, d, d, d, d, d, e, e, e, e, e, e, e, f, f, f, f, f, f, f, g, g, g, g, g, g, g, g, g, g, g, g, h, h, i, i, i, i, i, j, j, j, k, k, k, l, l, l, l, l, l, m, m, m, m, m, n, n, n, n, o, o, o, o, o, o, p, q, q, q, r, r, r, r, r, r, r, r, r, r, r, s, s, s, s, s, s, s, t, t, t, t, t, t, t, t, t, u, u, u, u, u, u, u, v, v, v, w, w, w, w, w, w, w, w, w, x, x, x, x, x, x, x, x, x, x, x, y, y, y, z, z, z
# + bausx,exgdx,exrigt,fdrzycftr,fvbtrr,mkcbfol,nxgfnye,ofvewaqjmo,oliexedpuw,qtmw,uggngquocg,ulgifdxa,wlmg,wsnhtkwis,wutzhixr,xvdcjrs,ygjlmr,zkust
#  : Should be bausx,exgdx,exrigt,fdrzycftr,fvbtrr,mkcbfol,nxgfnye,ofvewaqjmo,oliexedpuw,qtmw,uggngquocg,ulgifdxa,wlmg,wsnhtkwis,wutzhixr,xvdcjrs,ygjlmr,zkust
#
# ======================================================================
# FAIL: runTest (testing.test_alpha.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\isabel.lopes\OneDrive - XPLOR SOLUTIONS\PythonForAISolutions\WEEK2\Functions\testing.py", line 187, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: ', , , , , , , , , a, a, a, a, a, a, c, c,[214 chars]z, z' != 'aanpotcplc,cgtpvoq,lmhvzjp,rnahpmy,taik,t[36 chars]tixi'
# - , , , , , , , , , a, a, a, a, a, a, c, c, c, c, c, e, e, e, e, g, h, h, i, i, i, i, i, j, k, k, k, k, l, l, l, l, m, m, m, m, m, m, n, n, n, n, n, o, o, p, p, p, p, p, p, p, p, p, q, q, q, r, r, r, r, t, t, t, t, t, v, v, v, v, w, w, x, y, y, y, y, y, z, z, z
# + aanpotcplc,cgtpvoq,lmhvzjp,rnahpmy,taik,tllazecrn,vvmmqikyae,wnqp,wrmrmepky,ztixi
#  : Should be aanpotcplc,cgtpvoq,lmhvzjp,rnahpmy,taik,tllazecrn,vvmmqikyae,wnqp,wrmrmepky,ztixi
#
# ======================================================================
# FAIL: runTest (testing.test_alpha.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\isabel.lopes\OneDrive - XPLOR SOLUTIONS\PythonForAISolutions\WEEK2\Functions\testing.py", line 187, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: ', , , , , , , , a, a, a, a, a, b, b, b, b[185 chars]y, z' != 'gjovnb,ibtlkab,ikfnr,lgaaahvsx,nqqio,sdzh[27 chars]bnkr'
# - , , , , , , , , a, a, a, a, a, b, b, b, b, b, b, c, d, d, e, f, g, g, g, h, h, h, i, i, i, j, k, k, k, l, l, m, n, n, n, n, n, n, n, o, o, o, p, q, q, r, r, r, r, r, r, s, s, s, s, t, t, u, u, u, u, v, v, v, w, w, x, x, x, y, y, z
# + gjovnb,ibtlkab,ikfnr,lgaaahvsx,nqqio,sdzhpru,trmydase,wnscuhn,wxvuygbnkr
#  : Should be gjovnb,ibtlkab,ikfnr,lgaaahvsx,nqqio,sdzhpru,trmydase,wnscuhn,wxvuygbnkr
#
# ======================================================================
# FAIL: runTest (testing.test_alpha.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\isabel.lopes\OneDrive - XPLOR SOLUTIONS\PythonForAISolutions\WEEK2\Functions\testing.py", line 187, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: ', , , , , , , , a, a, b, b, b, c, c, c, d[185 chars]z, z' != 'cwdrxxlsie,fnfst,ggczz,mofah,rfnbosndpr,s[27 chars]kmnz'
# - , , , , , , , , a, a, b, b, b, c, c, c, d, d, d, d, e, e, e, f, f, f, f, f, f, g, g, g, g, h, h, h, h, i, i, k, k, k, l, m, m, n, n, n, n, o, o, p, r, r, r, r, r, r, s, s, s, s, s, s, t, t, t, u, v, w, x, x, y, z, z, z, z, z, z, z
# + cwdrxxlsie,fnfst,ggczz,mofah,rfnbosndpr,sarcfthshg,syrfbbekd,uizv,zkkmnz
#  : Should be cwdrxxlsie,fnfst,ggczz,mofah,rfnbosndpr,sarcfthshg,syrfbbekd,uizv,zkkmnz
#
# ======================================================================
# FAIL: runTest (testing.test_alpha.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\isabel.lopes\OneDrive - XPLOR SOLUTIONS\PythonForAISolutions\WEEK2\Functions\testing.py", line 187, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: ', , , , , , , , , , , , , , , , , , a, a,[412 chars]z, z' != 'ayil,buhdgvpvv,dvoczwz,dwoad,fzxtqy,gbsnb[96 chars]zqoa'
# - , , , , , , , , , , , , , , , , , , a, a, a, a, a, a, a, a, a, a, a, b, b, b, b, b, b, c, c, c, c, c, c, d, d, d, d, d, d, d, d, e, e, f, f, g, g, g, h, h, h, h, i, i, i, j, k, k, k, k, k, k, l, l, l, l, l, l, l, l, m, m, m, n, n, n, n, n, n, n, o, o, o, o, o, o, o, p, q, q, q, q, q, q, q, q, r, r, r, r, r, r, r, r, s, s, t, t, t, t, t, t, t, t, u, u, u, u, u, v, v, v, v, v, v, v, v, v, v, v, v, v, v, v, w, w, w, w, x, x, x, x, x, y, y, y, z, z, z, z, z
# + ayil,buhdgvpvv,dvoczwz,dwoad,fzxtqy,gbsnbv,igvqua,ijqr,kftt,msmrlmclhn,tbav,tnleqrccob,varrdoutn,vtovv,wkqwq,xknuac,xrkhlledk,xrxadhuola,zqoa
#  : Should be ayil,buhdgvpvv,dvoczwz,dwoad,fzxtqy,gbsnbv,igvqua,ijqr,kftt,msmrlmclhn,tbav,tnleqrccob,varrdoutn,vtovv,wkqwq,xknuac,xrkhlledk,xrxadhuola,zqoa
#
# ======================================================================
# FAIL: runTest (testing.test_alpha.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\isabel.lopes\OneDrive - XPLOR SOLUTIONS\PythonForAISolutions\WEEK2\Functions\testing.py", line 187, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: ', , , , , , , , , , a, a, a, a, a, a, b, [237 chars]z, z' != 'bfjmwnteut,bpzauk,brhvpxjxdm,dqnoryrigx,h[43 chars]ahgb'
# - , , , , , , , , , , a, a, a, a, a, a, b, b, b, b, b, b, b, c, c, d, d, d, e, f, f, g, g, g, h, h, h, h, h, h, i, i, j, j, j, j, j, k, k, k, k, k, m, m, m, m, m, n, n, n, o, p, p, p, p, q, q, r, r, r, r, r, s, s, t, t, t, u, u, u, u, u, u, u, u, v, w, x, x, x, x, x, x, x, y, y, z, z
# + bfjmwnteut,bpzauk,brhvpxjxdm,dqnoryrigx,hpck,huxjfu,pbuh,sgryua,usaircdj,xaqm,xknbtzahgb
#  : Should be bfjmwnteut,bpzauk,brhvpxjxdm,dqnoryrigx,hpck,huxjfu,pbuh,sgryua,usaircdj,xaqm,xknbtzahgb
#
# ======================================================================
# FAIL: runTest (testing.test_alpha.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\isabel.lopes\OneDrive - XPLOR SOLUTIONS\PythonForAISolutions\WEEK2\Functions\testing.py", line 187, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: ', , , , , , , , , , , , , , , , a, b, b, [369 chars]z, z' != 'ehhox,eyxgxwm,guyf,hsgbhyo,kjgbl,kpmi,kzw[83 chars]iren'
# - , , , , , , , , , , , , , , , , a, b, b, b, b, b, b, b, c, c, c, d, e, e, e, f, f, f, f, g, g, g, g, g, g, g, g, h, h, h, h, h, h, h, i, i, i, i, i, i, i, i, j, j, j, k, k, k, k, k, k, l, l, l, l, l, m, m, m, m, n, n, n, n, n, n, n, n, o, o, o, o, o, o, p, p, p, p, p, p, p, p, p, q, q, q, q, q, q, r, r, r, r, r, s, s, s, s, s, t, u, u, u, u, u, v, v, w, w, w, w, w, x, x, x, x, x, x, y, y, y, y, y, y, z, z, z, z
# + ehhox,eyxgxwm,guyf,hsgbhyo,kjgbl,kpmi,kzwibhh,ltrcgfisk,nyalibpn,qdjjzvmgmb,qoqp,qupqnqprxg,ucrofopw,vbyyp,xklwi,znsucrs,zuniren
#  : Should be ehhox,eyxgxwm,guyf,hsgbhyo,kjgbl,kpmi,kzwibhh,ltrcgfisk,nyalibpn,qdjjzvmgmb,qoqp,qupqnqprxg,ucrofopw,vbyyp,xklwi,znsucrs,zuniren
#
# ======================================================================
# FAIL: runTest (testing.test_alpha.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\isabel.lopes\OneDrive - XPLOR SOLUTIONS\PythonForAISolutions\WEEK2\Functions\testing.py", line 187, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: ', , , , , , , , , , , , , , , , , , , , ,[578 chars]z, z' != 'aawe,averpbuw,bckrqayxu,bduvo,brvemyvab,c[148 chars]olvj'
# Diff is 823 characters long. Set self.maxDiff to None to see it. : Should be aawe,averpbuw,bckrqayxu,bduvo,brvemyvab,csswwi,echlxzcht,fiifg,fjeagsyp,gstzhrmz,hiovqi,jklhshq,jvggkni,loznvyl,nlnohje,oxtpmdtxwy,powehnum,qvrq,runtojgxdf,tfze,uyivcb,xrouddpjl,yakuycjrr,yolvj
#
# ======================================================================
# FAIL: runTest (testing.test_alpha.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\isabel.lopes\OneDrive - XPLOR SOLUTIONS\PythonForAISolutions\WEEK2\Functions\testing.py", line 187, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: ', , , , , , , , , , , , , , , , , , , , ,[632 chars]z, z' != 'cxfhgtwszq,damikbnz,djixggsih,dwprd,eqfz,[166 chars]makj'
# Diff is 895 characters long. Set self.maxDiff to None to see it. : Should be cxfhgtwszq,damikbnz,djixggsih,dwprd,eqfz,fgdvtuqd,jdii,jiprece,khnfcfxdh,khyupdkovf,ksrkshfnwx,lngr,ncblhdhqs,olmrfkxth,oukoroxp,ovwo,pgruiirlv,pztxztwdit,qgcbslmbbt,rrzdibw,sjgqbimggf,whqqxqhdhr,yqipb,ytzbamakj
#
# ======================================================================
# FAIL: runTest (testing.test_alpha.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\isabel.lopes\OneDrive - XPLOR SOLUTIONS\PythonForAISolutions\WEEK2\Functions\testing.py", line 187, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: ', , , , , , , , , , , , a, a, a, a, a, a,[313 chars]z, z' != 'araiqtm,arrqxpueyn,davvye,jmiartmo,jyucvf[67 chars]wyyt'
# - , , , , , , , , , , , , a, a, a, a, a, a, b, b, b, c, c, c, d, d, d, e, e, e, e, e, e, f, f, f, g, g, i, i, i, i, i, i, j, j, j, j, j, j, l, l, l, l, m, m, m, m, m, m, n, n, n, n, n, o, o, o, p, p, p, p, p, p, q, q, q, q, q, r, r, r, r, r, r, r, r, t, t, t, t, t, t, t, u, u, v, v, v, v, v, w, w, w, w, w, w, x, x, x, x, x, y, y, y, y, y, y, y, y, z, z, z, z
# + araiqtm,arrqxpueyn,davvye,jmiartmo,jyucvfoxvw,nzflet,pczbcbp,pnxbamjddj,qixprlmy,rwlfinvir,yglq,zjtwgixwe,zrwyyt
#  : Should be araiqtm,arrqxpueyn,davvye,jmiartmo,jyucvfoxvw,nzflet,pczbcbp,pnxbamjddj,qixprlmy,rwlfinvir,yglq,zjtwgixwe,zrwyyt
#
# ======================================================================
# FAIL: runTest (testing.test_alpha.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\isabel.lopes\OneDrive - XPLOR SOLUTIONS\PythonForAISolutions\WEEK2\Functions\testing.py", line 187, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: ', , , , , , , , , , , , , , , , , , , , ,[577 chars]z, z' != 'apuqocyujn,bkddfj,cfwrl,cubs,detvsv,eslkv[147 chars]obpy'
# Diff is 821 characters long. Set self.maxDiff to None to see it. : Should be apuqocyujn,bkddfj,cfwrl,cubs,detvsv,eslkv,fthsmlbpcp,fwtwflc,gwwucad,keqeoacc,khpdrmpn,kjmplyuofc,mwxwfqaa,nkiakc,odtv,oxoirs,ppirhnhw,qwac,qwuoa,uazgmobviv,uhxig,utaryx,wbdypo,ylbys,zzvzqobpy
#
# ======================================================================
# FAIL: runTest (testing.test_alpha.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\isabel.lopes\OneDrive - XPLOR SOLUTIONS\PythonForAISolutions\WEEK2\Functions\testing.py", line 187, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: ', , , , , , a, a, a, b, b, c, c, c, c, d,[160 chars]z, z' != 'cshtabphff,ecijauj,grdx,syopyvuhag,tzsdmo[20 chars]nocw'
# - , , , , , , a, a, a, b, b, c, c, c, c, d, d, e, e, f, f, f, g, g, g, h, h, h, h, i, j, j, j, m, n, n, o, o, o, p, p, p, p, p, p, q, r, s, s, s, t, t, t, u, u, u, v, v, v, w, w, w, x, x, x, y, y, z, z, z, z
# + cshtabphff,ecijauj,grdx,syopyvuhag,tzsdmotnpz,wbpqvevzp,xzchunocw
#  : Should be cshtabphff,ecijauj,grdx,syopyvuhag,tzsdmotnpz,wbpqvevzp,xzchunocw
#
# ======================================================================
# FAIL: runTest (testing.test_alpha.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\isabel.lopes\OneDrive - XPLOR SOLUTIONS\PythonForAISolutions\WEEK2\Functions\testing.py", line 187, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: ', , , , , , , , , , , a, a, a, a, a, b, b[239 chars]z, z' != 'eeaukyjafj,hacqr,hxvaw,hxxbw,isbsktmhdn,k[43 chars]yoqt'
# - , , , , , , , , , , , a, a, a, a, a, b, b, c, c, d, d, d, e, e, f, f, f, g, h, h, h, h, h, i, j, j, j, j, k, k, k, k, l, m, m, m, m, m, n, n, n, n, o, o, o, o, q, q, q, r, r, r, r, s, s, t, t, t, t, t, t, t, u, u, v, v, w, w, w, w, w, w, w, x, x, x, x, x, x, y, y, y, y, z, z, z, z, z
# + eeaukyjafj,hacqr,hxvaw,hxxbw,isbsktmhdn,kgozvmt,nrucmz,ntqkoztw,wzdjlyam,xrhf,ydfox,yoqt
#  : Should be eeaukyjafj,hacqr,hxvaw,hxxbw,isbsktmhdn,kgozvmt,nrucmz,ntqkoztw,wzdjlyam,xrhf,ydfox,yoqt
#
# ======================================================================
# FAIL: runTest (testing.test_alpha.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\isabel.lopes\OneDrive - XPLOR SOLUTIONS\PythonForAISolutions\WEEK2\Functions\testing.py", line 187, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: ', , , , , , , , , , , , , , , , , , , a, [510 chars]z, z' != 'bufxg,csirpdgvaw,cytzxe,dwjolbarj,fxcnydw[128 chars]ltiy'
# Diff is 735 characters long. Set self.maxDiff to None to see it. : Should be bufxg,csirpdgvaw,cytzxe,dwjolbarj,fxcnydw,gjrqogjk,heobjblih,hkiin,hphfgfacs,kxfwep,lopazokpwy,lsseboivj,mbqullxsay,oeyfbsf,pphlrsgu,quxc,they,tpakoiahy,wkdmgxigh,zouvovltiy
#
# ======================================================================
# FAIL: runTest (testing.test_alpha.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\isabel.lopes\OneDrive - XPLOR SOLUTIONS\PythonForAISolutions\WEEK2\Functions\testing.py", line 187, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: ', , , , , , , a, a, a, b, c, d, d, d, d, [183 chars]z, z' != 'ahyq,djjsjp,gzdrnywpjv,jjzzisigyg,nzyqgdc[27 chars]vgxy'
# - , , , , , , , a, a, a, b, c, d, d, d, d, d, g, g, g, g, g, g, g, g, h, i, i, i, i, j, j, j, j, j, j, k, m, m, n, n, p, p, p, p, q, q, q, q, r, r, s, s, t, t, u, v, v, v, w, x, y, y, y, y, y, y, y, y, y, y, y, y, y, z, z, z, z, z
# + ahyq,djjsjp,gzdrnywpjv,jjzzisigyg,nzyqgdcp,tqzrbyaiyd,yggtiuay,ymkymvgxy
#  : Should be ahyq,djjsjp,gzdrnywpjv,jjzzisigyg,nzyqgdcp,tqzrbyaiyd,yggtiuay,ymkymvgxy
#
# ======================================================================
# FAIL: runTest (testing.test_alpha.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\isabel.lopes\OneDrive - XPLOR SOLUTIONS\PythonForAISolutions\WEEK2\Functions\testing.py", line 187, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: ', , , , , , , a, a, b, b, b, c, c, d, d, [144 chars]z, z' != 'cnnt,csbvwiy,dhhoirlro,dwfbvhaez,jzzpw,lb[14 chars]zxyf'
# - , , , , , , , a, a, b, b, b, c, c, d, d, e, f, f, f, h, h, h, h, i, i, j, k, l, l, n, n, n, n, n, o, o, o, p, r, r, s, t, t, u, v, v, v, v, w, w, w, w, w, w, x, x, x, y, y, y, z, z, z, z, z
# + cnnt,csbvwiy,dhhoirlro,dwfbvhaez,jzzpw,lbkaywhnvx,uvwn,zxyf
#  : Should be cnnt,csbvwiy,dhhoirlro,dwfbvhaez,jzzpw,lbkaywhnvx,uvwn,zxyf
#
# ======================================================================
# FAIL: runTest (testing.test_alpha.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\isabel.lopes\OneDrive - XPLOR SOLUTIONS\PythonForAISolutions\WEEK2\Functions\testing.py", line 187, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: ', , , , , , , , , , , , a, a, a, a, a, a,[286 chars]z, z' != 'abso,cmguja,daslkfbup,dessysdo,ehgvflg,eq[58 chars]cjvg'
# - , , , , , , , , , , , , a, a, a, a, a, a, b, b, b, c, c, d, d, d, d, d, d, e, e, e, e, e, e, f, f, f, f, f, g, g, g, g, g, g, h, h, h, h, h, h, j, j, j, j, j, k, k, k, k, k, k, l, l, l, l, m, m, m, m, n, n, n, o, o, o, o, o, o, o, o, p, p, p, p, q, q, q, r, r, r, s, s, s, s, s, s, s, u, u, u, v, v, v, v, v, w, x, y, y, y, y, z, z
# + abso,cmguja,daslkfbup,dessysdo,ehgvflg,eqfenydwok,haommbh,mlvf,njnpzued,qkqehrvjl,roak,rxoypyvjhs,zcjvg
#  : Should be abso,cmguja,daslkfbup,dessysdo,ehgvflg,eqfenydwok,haommbh,mlvf,njnpzued,qkqehrvjl,roak,rxoypyvjhs,zcjvg
#
# ======================================================================
# FAIL: runTest (testing.test_alpha.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\isabel.lopes\OneDrive - XPLOR SOLUTIONS\PythonForAISolutions\WEEK2\Functions\testing.py", line 187, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: ', , , , , , , , , , , , , , , , , , , , a[512 chars]z, z' != 'blyool,cpevknb,cphrhx,gdpsxixzi,gvbgaomxd[128 chars]rpzt'
# Diff is 737 characters long. Set self.maxDiff to None to see it. : Should be blyool,cpevknb,cphrhx,gdpsxixzi,gvbgaomxdi,hbjbiqv,hmtrnyfc,isfox,jjjgksqxcn,lzcg,oksnlzsguo,rnoswbts,rvwr,sdowcmx,tddllc,tfbjmfpt,ufzwlz,ukaz,wqkfaepj,wquoxqvpcr,yrzpghrpzt
#
# ======================================================================
# FAIL: runTest (testing.test_alpha.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\isabel.lopes\OneDrive - XPLOR SOLUTIONS\PythonForAISolutions\WEEK2\Functions\testing.py", line 187, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: ', , , , , , , , , , , , , , , , , , , , ,[507 chars]z, z' != 'drjvuavl,ekbq,gvhwkbwkz,ioidqivxb,izrambk[125 chars]cdyw'
# Diff is 729 characters long. Set self.maxDiff to None to see it. : Should be drjvuavl,ekbq,gvhwkbwkz,ioidqivxb,izrambk,jxppb,mslgcwwtiv,olodx,otjwf,pnmxa,pohoahvnn,ptknncth,sdpd,siopx,tbcmw,tfdw,waas,wdtz,xaddczro,xhcnnangkc,xwbyavol,yqeo,zlrrcdyw
#
# ======================================================================
# FAIL: runTest (testing.test_alpha.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\isabel.lopes\OneDrive - XPLOR SOLUTIONS\PythonForAISolutions\WEEK2\Functions\testing.py", line 187, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: ', , , , , , , , , a, a, a, a, a, b, b, b,[208 chars]y, y' != 'apkivkpb,etvyjgl,gcgq,ilpvtvmia,jsipptg,l[34 chars]ayuu'
# - , , , , , , , , , a, a, a, a, a, b, b, b, b, c, c, d, d, e, g, g, g, g, g, i, i, i, i, i, i, j, j, k, k, k, k, l, l, l, l, l, l, l, l, l, l, l, m, m, m, o, o, o, p, p, p, p, p, p, p, p, q, q, q, r, s, s, t, t, t, t, u, u, u, v, v, v, v, v, w, w, y, y, y
# + apkivkpb,etvyjgl,gcgq,ilpvtvmia,jsipptg,lltpwgl,lmiqalp,mrwskyicol,ododb,vkayuu
#  : Should be apkivkpb,etvyjgl,gcgq,ilpvtvmia,jsipptg,lltpwgl,lmiqalp,mrwskyicol,ododb,vkayuu
#
# ======================================================================
# FAIL: runTest (testing.test_alpha.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\isabel.lopes\OneDrive - XPLOR SOLUTIONS\PythonForAISolutions\WEEK2\Functions\testing.py", line 187, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: ', , , , b, b, b, b, b, c, d, d, e, e, g, [87 chars]z, z' != 'bevcvmd,boiljvwui,eyurpbz,vjjwzlgzb,wwgbrk'
# - , , , , b, b, b, b, b, c, d, d, e, e, g, g, i, i, i, j, j, j, k, k, l, l, m, o, p, r, r, u, u, v, v, v, v, w, w, w, w, y, z, z, z, z
# + bevcvmd,boiljvwui,eyurpbz,vjjwzlgzb,wwgbrk
#  : Should be bevcvmd,boiljvwui,eyurpbz,vjjwzlgzb,wwgbrk
#
# ======================================================================
# FAIL: runTest (testing.test_alpha.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\isabel.lopes\OneDrive - XPLOR SOLUTIONS\PythonForAISolutions\WEEK2\Functions\testing.py", line 187, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: ', , , , , , , , , , , , , , , , , a, a, a[380 chars]z, z' != 'bxfrmejb,eklr,eocrb,hbatjoeop,irzjouocjc,[86 chars]ztmm'
# - , , , , , , , , , , , , , , , , , a, a, a, a, a, a, a, b, b, b, b, b, b, b, c, c, c, c, c, c, d, e, e, e, e, f, f, f, f, g, g, g, h, h, i, i, i, i, i, i, j, j, j, j, j, j, j, j, j, k, k, k, k, k, l, l, l, l, m, m, m, m, m, m, m, m, m, m, m, n, n, o, o, o, o, o, o, o, o, o, o, o, p, p, p, p, p, q, q, q, q, r, r, r, r, r, r, r, r, r, s, s, t, t, u, u, u, u, u, u, v, v, v, w, x, x, x, x, x, x, y, y, y, y, y, y, z, z, z, z, z
# + bxfrmejb,eklr,eocrb,hbatjoeop,irzjouocjc,jyjfjay,lmakoxm,mdfoqa,mmyrx,pcyqunu,qgnl,soix,vgiqoa,vumoz,wkgurk,yfbvhpobr,zpiscjji,ztmm
#  : Should be bxfrmejb,eklr,eocrb,hbatjoeop,irzjouocjc,jyjfjay,lmakoxm,mdfoqa,mmyrx,pcyqunu,qgnl,soix,vgiqoa,vumoz,wkgurk,yfbvhpobr,zpiscjji,ztmm
#
# ======================================================================
# FAIL: runTest (testing.test_alpha.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\isabel.lopes\OneDrive - XPLOR SOLUTIONS\PythonForAISolutions\WEEK2\Functions\testing.py", line 187, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: ', , , , , , , , , , , a, a, b, c, c, d, d[266 chars]y, z' != 'ehnmhsw,hqjjpa,jxtj,ndvbnym,nrmnqxf,ophiu[52 chars]qcvm'
# - , , , , , , , , , , , a, a, b, c, c, d, d, d, d, e, e, e, e, f, f, f, g, g, h, h, h, h, h, h, i, j, j, j, j, j, j, k, l, l, m, m, m, m, m, m, m, n, n, n, n, n, n, o, o, o, p, p, p, p, p, p, p, q, q, q, q, q, q, r, r, s, s, s, t, t, t, t, u, u, v, v, v, v, v, v, v, w, w, x, x, x, x, x, y, y, y, y, y, y, y, y, z
# + ehnmhsw,hqjjpa,jxtj,ndvbnym,nrmnqxf,ophiup,srvxey,tddeyyhy,tfkhvl,vpojnqqoev,xscpuyqgmp,ztdgxqcvm
#  : Should be ehnmhsw,hqjjpa,jxtj,ndvbnym,nrmnqxf,ophiup,srvxey,tddeyyhy,tfkhvl,vpojnqqoev,xscpuyqgmp,ztdgxqcvm
#
# ======================================================================
# FAIL: runTest (testing.test_alpha.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\isabel.lopes\OneDrive - XPLOR SOLUTIONS\PythonForAISolutions\WEEK2\Functions\testing.py", line 187, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: ', , , , , , , , , , , , , , , b, b, b, b,[316 chars]z, z' != 'bybf,ckrfz,csdo,cuwnjfb,esrqz,fofsrt,gthl[66 chars]bxlq'
# - , , , , , , , , , , , , , , , b, b, b, b, b, b, c, c, c, c, c, c, d, d, d, d, e, e, e, e, f, f, f, f, f, f, f, g, g, g, g, h, h, h, h, i, i, i, i, j, j, k, k, l, l, l, l, m, m, m, m, m, m, n, n, o, o, o, o, o, o, p, p, p, q, q, q, q, q, q, q, r, r, r, r, r, r, r, s, s, s, s, s, s, s, s, t, t, t, t, t, u, v, v, v, v, v, w, w, x, x, x, y, y, y, y, z, z, z, z, z
# + bybf,ckrfz,csdo,cuwnjfb,esrqz,fofsrt,gthldjsrc,iszhxfzbo,qegq,qipevhpdl,rvmem,tvmocnr,vpti,xdywkm,ygvgss,yhbxlq
#  : Should be bybf,ckrfz,csdo,cuwnjfb,esrqz,fofsrt,gthldjsrc,iszhxfzbo,qegq,qipevhpdl,rvmem,tvmocnr,vpti,xdywkm,ygvgss,yhbxlq
#
# ======================================================================
# FAIL: runTest (testing.test_alpha.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\isabel.lopes\OneDrive - XPLOR SOLUTIONS\PythonForAISolutions\WEEK2\Functions\testing.py", line 187, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: ', , , , , , , , , , , , , , , , , , , a, [498 chars]z, z' != 'aopghixti,cjogcchuno,drubnpqdh,ecszyxpkq,[124 chars]haua'
# Diff is 719 characters long. Set self.maxDiff to None to see it. : Should be aopghixti,cjogcchuno,drubnpqdh,ecszyxpkq,eplrmc,ezwphfz,gcyamblq,iclaiej,iioeh,jadbmivuf,ncknhn,nearqcfzrv,nhyms,omcohldt,pgfs,sufedsml,ueuyuzvzge,ufxpgk,xvnved,yhxehaua
#
# ======================================================================
# FAIL: runTest (testing.test_alpha.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\isabel.lopes\OneDrive - XPLOR SOLUTIONS\PythonForAISolutions\WEEK2\Functions\testing.py", line 187, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: ', , , , , , , , , a, a, a, b, b, b, c, c,[238 chars]z, z' != 'bayzwjgw,cseyuxsz,cvefmki,damp,eqfpoixbrg[44 chars]zhqu'
# - , , , , , , , , , a, a, a, b, b, b, c, c, c, d, d, d, e, e, e, e, e, e, f, f, f, g, g, g, g, g, g, g, h, i, i, i, i, j, j, k, k, k, m, m, m, m, m, n, o, o, p, p, p, q, q, q, q, q, r, r, s, s, s, s, s, s, t, t, t, t, u, u, u, u, v, w, w, w, w, w, x, x, y, y, y, y, y, z, z, z, z, z, z
# + bayzwjgw,cseyuxsz,cvefmki,damp,eqfpoixbrg,fetuesdmss,jrywqtwkty,ogcmnqbzg,qtdmega,zikzhqu
#  : Should be bayzwjgw,cseyuxsz,cvefmki,damp,eqfpoixbrg,fetuesdmss,jrywqtwkty,ogcmnqbzg,qtdmega,zikzhqu
#
# ======================================================================
# FAIL: runTest (testing.test_alpha.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\isabel.lopes\OneDrive - XPLOR SOLUTIONS\PythonForAISolutions\WEEK2\Functions\testing.py", line 187, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: ', , , , , a, c, e, f, f, g, g, g, h, i, i[116 chars]z, z' != 'feilgusku,fmkjliscl,mgupwamvhk,pzyy,tgqiynjvnl,zwxz'
# - , , , , , a, c, e, f, f, g, g, g, h, i, i, i, j, j, k, k, k, k, l, l, l, l, l, l, m, m, m, n, n, p, p, q, s, s, t, u, u, u, v, v, w, w, x, y, y, y, y, z, z, z, z
# + feilgusku,fmkjliscl,mgupwamvhk,pzyy,tgqiynjvnl,zwxz
#  : Should be feilgusku,fmkjliscl,mgupwamvhk,pzyy,tgqiynjvnl,zwxz
#
# ======================================================================
# FAIL: runTest (testing.test_alpha.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
# ...
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: ', , , , , , , , , , , , , , , , , , , , ,[637 chars]z, z' != 'bjmrjoha,ccqtdwg,cpoud,cytgalhdry,edcrbkf[167 chars]sgui'
# Diff is 901 characters long. Set self.maxDiff to None to see it. : Should be bjmrjoha,ccqtdwg,cpoud,cytgalhdry,edcrbkfjy,hmyblg,hqpnn,ijhjym,ikfm,izgnhj,lvlhgtnmc,nkzpggvzfx,nubyjgx,nyudfgc,pcxlmk,pejmbso,ruhrtvvwyf,sdwqahx,tzophr,wtfktyebnj,xcoaeyysbd,xdksvw,ympipwildv,ywptrfnuce,zjnsgui
#
# ======================================================================
# FAIL: runTest (testing.test_alpha.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\isabel.lopes\OneDrive - XPLOR SOLUTIONS\PythonForAISolutions\WEEK2\Functions\testing.py", line 187, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: ', , , , , , , , , , , , , , , , , a, a, a[443 chars]z, z' != 'dpzeog,dxvbkzhmh,ermecule,fqpmny,gqyot,hc[107 chars]ulqk'
# Diff is 647 characters long. Set self.maxDiff to None to see it. : Should be dpzeog,dxvbkzhmh,ermecule,fqpmny,gqyot,hcibsvd,igrmsvauwl,kxqur,luys,mqqrflzs,qgyaehej,tldddh,wbdwzqxram,whbrxygyl,ycwgnbtnty,yhkfcgx,yudxnoira,zhbuulqk
#
# ======================================================================
# FAIL: runTest (testing.test_alpha.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\isabel.lopes\OneDrive - XPLOR SOLUTIONS\PythonForAISolutions\WEEK2\Functions\testing.py", line 187, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: ', , , , , , , , , , , , , , , , , , , , ,[496 chars]z, z' != 'bvyeczlaqb,fhlnogdk,gnbowk,gzqq,hrdlmjkq,[122 chars]ibmv'
# Diff is 715 characters long. Set self.maxDiff to None to see it. : Should be bvyeczlaqb,fhlnogdk,gnbowk,gzqq,hrdlmjkq,iobvhle,kehdywucy,kypglaryr,lipf,qohked,rxwddk,sfsi,syvzhdyd,tkabx,vngxpufrqx,whwwuv,xbaureb,xkxbrj,yeiv,yzbhxg,zmavbfd,zpibmv
#
# ======================================================================
# FAIL: runTest (testing.test_alpha.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\isabel.lopes\OneDrive - XPLOR SOLUTIONS\PythonForAISolutions\WEEK2\Functions\testing.py", line 187, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: ', , , , , , , , , , , , a, a, a, a, b, b,[256 chars]z, z' != 'aiuyg,flwjxrft,fskjm,jvlwa,ncgbf,owog,ufg[48 chars]rklk'
# - , , , , , , , , , , , , a, a, a, a, b, b, c, c, c, d, e, f, f, f, f, f, f, f, g, g, g, g, g, g, g, i, i, i, i, i, i, j, j, j, j, j, j, j, j, k, k, k, k, l, l, l, l, m, m, m, m, n, n, o, o, o, p, p, r, r, s, s, s, t, t, t, t, t, u, u, u, u, v, v, v, v, w, w, w, w, w, w, x, x, x, x, y, y, y, y, z, z, z
# + aiuyg,flwjxrft,fskjm,jvlwa,ncgbf,owog,ufgtp,uyialsiduj,wgfzywvoi,wimc,xstj,ybmnxtzj,zevxvrklk
#  : Should be aiuyg,flwjxrft,fskjm,jvlwa,ncgbf,owog,ufgtp,uyialsiduj,wgfzywvoi,wimc,xstj,ybmnxtzj,zevxvrklk
#
# ======================================================================
# FAIL: runTest (testing.test_alpha.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\isabel.lopes\OneDrive - XPLOR SOLUTIONS\PythonForAISolutions\WEEK2\Functions\testing.py", line 187, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: ', , , , , , , , , , , , , , , a, a, a, a,[328 chars]z, z' != 'aglzain,aybeh,buygdgztek,dede,gadazcz,gpb[70 chars]qcvh'
# - , , , , , , , , , , , , , , , a, a, a, a, a, a, a, a, b, b, b, b, b, c, c, c, c, d, d, d, d, d, e, e, e, e, e, e, e, e, f, f, f, f, f, g, g, g, g, g, g, g, g, g, h, h, h, h, h, h, i, j, j, j, k, k, k, l, l, l, l, l, m, m, m, m, n, n, n, n, n, n, o, o, p, p, p, p, p, p, q, q, r, r, r, r, r, r, r, r, r, t, t, u, u, v, v, v, v, x, x, y, y, y, y, y, z, z, z, z, z, z, z, z, z
# + aglzain,aybeh,buygdgztek,dede,gadazcz,gpble,kgbftynr,mjlpec,nrelyf,pvmzjp,qvmoz,rhfa,ruzmjhr,vxodr,xplnnagbfg,yqcvh
#  : Should be aglzain,aybeh,buygdgztek,dede,gadazcz,gpble,kgbftynr,mjlpec,nrelyf,pvmzjp,qvmoz,rhfa,ruzmjhr,vxodr,xplnnagbfg,yqcvh
#
# ======================================================================
# FAIL: runTest (testing.test_alpha.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\isabel.lopes\OneDrive - XPLOR SOLUTIONS\PythonForAISolutions\WEEK2\Functions\testing.py", line 187, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: ', , , , , , , , , , , , , , , , , , , , ,[487 chars]z, z' != 'akpcy,ellvd,gmpu,heenvxqmyc,jaiydnd,jjbpj[119 chars]rmfk'
# Diff is 703 characters long. Set self.maxDiff to None to see it. : Should be akpcy,ellvd,gmpu,heenvxqmyc,jaiydnd,jjbpj,keqrvt,kkxnfwx,lnxvn,mevsljx,qknkkof,qwxzmuvt,riwybk,rpfxbahzyo,rxlvwzh,sdarxk,tjltfshsq,uqav,urfkp,vftam,wfwuujxm,ylyrmfk
#
# ======================================================================
# FAIL: runTest (testing.test_alpha.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\isabel.lopes\OneDrive - XPLOR SOLUTIONS\PythonForAISolutions\WEEK2\Functions\testing.py", line 187, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: ', , , , , , , , , , , , , , , , , , , , ,[619 chars]z, z' != 'aelxgajdn,bhaz,blpxrjsmnm,bqefifk,bsgnci,[161 chars]zrvk'
# Diff is 877 characters long. Set self.maxDiff to None to see it. : Should be aelxgajdn,bhaz,blpxrjsmnm,bqefifk,bsgnci,djffofp,ejsltgkp,eudruifiwz,ffubcvqbh,fjkzgf,hcpuvb,htoqmqnl,hwxfoz,idsjbbsvs,mcbfwdgd,mhjs,mpjimnfzc,qweeesanr,rqui,sysujqpg,xbysbyfucb,xnrgu,ywlixze,ztucjipu,zzrvk
#
# ======================================================================
# FAIL: runTest (testing.test_alpha.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\isabel.lopes\OneDrive - XPLOR SOLUTIONS\PythonForAISolutions\WEEK2\Functions\testing.py", line 187, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: ', , , , , , , , , , , , , , , , , , , , a[470 chars]z, z' != 'cllggsby,cryxi,culymern,dlzcb,euvn,fwaltp[114 chars]hyfd'
# Diff is 681 characters long. Set self.maxDiff to None to see it. : Should be cllggsby,cryxi,culymern,dlzcb,euvn,fwaltped,gdvfiubxp,ivrkqvsl,jmbhgtaw,ocfqjx,ornjfjycly,pidrko,qksp,rpkj,sprwspur,svtfkz,vwpnglyui,wbkzypr,wkxe,xijsvbu,zhyfd
#
# ======================================================================
# FAIL: runTest (testing.test_alpha.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\isabel.lopes\OneDrive - XPLOR SOLUTIONS\PythonForAISolutions\WEEK2\Functions\testing.py", line 187, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: ', , , , , , , , , , , , , , , , , a, a, a[392 chars]z, z' != 'avmframkb,cpfhy,gfvlr,hfon,ibjnhxu,jqltgy[90 chars]eept'
# - , , , , , , , , , , , , , , , , , a, a, a, b, b, b, b, b, b, b, b, c, c, c, c, c, d, d, e, e, e, e, f, f, f, f, f, f, f, f, g, g, g, g, g, g, h, h, h, h, h, h, i, i, i, i, i, j, j, k, k, l, l, l, l, l, l, l, m, m, m, m, n, n, n, n, n, n, n, n, o, o, o, o, o, o, o, p, p, q, q, q, q, q, q, r, r, r, r, r, r, r, r, r, r, s, s, t, t, t, t, u, u, u, u, u, u, v, v, v, v, v, v, v, v, v, x, x, x, x, x, y, y, y, y, y, y, y, y, z, z, z, z, z, z
# + avmframkb,cpfhy,gfvlr,hfon,ibjnhxu,jqltgy,mrbfrl,neduutqgr,nesiqygody,oonh,ovffl,qycmnzzb,uhosni,vccxzo,xvfxr,xvkqilbcv,zbag,zqurvzeept
#  : Should be avmframkb,cpfhy,gfvlr,hfon,ibjnhxu,jqltgy,mrbfrl,neduutqgr,nesiqygody,oonh,ovffl,qycmnzzb,uhosni,vccxzo,xvfxr,xvkqilbcv,zbag,zqurvzeept
#
# ======================================================================
# FAIL: runTest (testing.test_alpha.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\isabel.lopes\OneDrive - XPLOR SOLUTIONS\PythonForAISolutions\WEEK2\Functions\testing.py", line 187, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: ', , , , , , , , , , , , , , , , , , , a, [477 chars]z, z' != 'bhzsc,dyoaum,efcgx,guheissvm,hidqjt,hvrkh[117 chars]jjvx'
# Diff is 691 characters long. Set self.maxDiff to None to see it. : Should be bhzsc,dyoaum,efcgx,guheissvm,hidqjt,hvrkhid,igonoznd,iqdy,jrhqs,jzranbk,lylcr,nkzclbgip,qmqsccrnpl,skaa,swdsibouw,tcuebwcw,tspgdlyacu,tzmamlyj,vjzmueng,vuusgrjjvx
#
# ======================================================================
# FAIL: runTest (testing.test_alpha.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\isabel.lopes\OneDrive - XPLOR SOLUTIONS\PythonForAISolutions\WEEK2\Functions\testing.py", line 187, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: ', , , , , , , , , a, a, a, a, a, a, a, a,[223 chars]z, z' != 'cpgxah,hhluahnnfh,jyimv,lwdsgy,nidirz,wir[39 chars]xmaa'
# - , , , , , , , , , a, a, a, a, a, a, a, a, a, b, b, c, c, c, d, d, e, e, f, g, g, h, h, h, h, h, h, h, h, i, i, i, i, i, j, j, j, j, j, j, k, l, l, l, l, l, m, m, m, m, n, n, n, n, p, p, q, r, r, r, r, s, u, v, v, w, w, w, w, x, x, x, x, y, y, y, y, y, y, z, z, z, z, z
# + cpgxah,hhluahnnfh,jyimv,lwdsgy,nidirz,wirxlnajb,wjzjaljr,wmmxzce,ylakjyyq,zciphaxmaa
#  : Should be cpgxah,hhluahnnfh,jyimv,lwdsgy,nidirz,wirxlnajb,wjzjaljr,wmmxzce,ylakjyyq,zciphaxmaa
#
# ======================================================================
# FAIL: runTest (testing.test_alpha.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\isabel.lopes\OneDrive - XPLOR SOLUTIONS\PythonForAISolutions\WEEK2\Functions\testing.py", line 187, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: ', , , , , , , , , a, a, b, b, c, c, d, d,[208 chars]z, z' != 'addz,fseco,guudrjhm,jkbajr,nqlydh,qdvmbtv[34 chars]csrn'
# - , , , , , , , , , a, a, b, b, c, c, d, d, d, d, d, e, e, f, f, g, h, h, h, i, i, j, j, j, k, k, k, l, l, m, m, m, n, n, n, n, o, o, o, o, p, p, p, q, q, q, q, q, r, r, r, r, r, r, s, s, s, t, t, t, t, t, u, u, u, u, v, v, w, w, w, x, x, y, z, z, z, z, z
# + addz,fseco,guudrjhm,jkbajr,nqlydh,qdvmbtvxlq,qwisowpuok,rwfxpzittt,uner,zzpcsrn
#  : Should be addz,fseco,guudrjhm,jkbajr,nqlydh,qdvmbtvxlq,qwisowpuok,rwfxpzittt,uner,zzpcsrn
#
# ======================================================================
# FAIL: runTest (testing.test_alpha.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\isabel.lopes\OneDrive - XPLOR SOLUTIONS\PythonForAISolutions\WEEK2\Functions\testing.py", line 187, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: ', , , , , , , , , , , , , , , , , a, a, a[407 chars]z, z' != 'bmlfbb,bxfjww,dnjuakpvg,imkg,jteimpw,ldyh[95 chars]zpni'
# - , , , , , , , , , , , , , , , , , a, a, a, a, a, a, b, b, b, b, b, b, b, b, c, d, d, d, d, d, d, e, e, e, f, f, f, f, g, g, g, g, g, h, h, h, h, h, h, h, h, i, i, i, i, i, i, i, j, j, j, j, j, j, j, k, k, k, l, l, l, l, l, l, l, l, m, m, m, m, m, m, m, n, n, n, n, n, n, n, o, o, o, o, p, p, p, p, q, q, r, r, r, r, s, s, t, t, t, t, t, u, u, u, u, u, u, u, u, v, v, v, v, v, v, v, v, v, v, w, w, w, w, w, w, w, w, w, x, x, x, x, y, y, y, y, z, z, z, z
# + bmlfbb,bxfjww,dnjuakpvg,imkg,jteimpw,ldyhjot,lnfubxo,mlunjdvi,mvwxvaqv,nczmuwka,rselnjqb,uuoh,uylxtplt,vehh,whnwmd,yafrjvldv,yushiargrz,zpni
#  : Should be bmlfbb,bxfjww,dnjuakpvg,imkg,jteimpw,ldyhjot,lnfubxo,mlunjdvi,mvwxvaqv,nczmuwka,rselnjqb,uuoh,uylxtplt,vehh,whnwmd,yafrjvldv,yushiargrz,zpni
#
# ======================================================================
# FAIL: runTest (testing.test_alpha.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\isabel.lopes\OneDrive - XPLOR SOLUTIONS\PythonForAISolutions\WEEK2\Functions\testing.py", line 187, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: ', , , , , , , , , , , , , , , , a, a, b, [405 chars]z, z' != 'emce,evii,fomowsjt,goxmh,hnslwh,jyfv,lvkx[95 chars]uwod'
# - , , , , , , , , , , , , , , , , a, a, b, b, c, c, c, d, d, d, d, e, e, e, e, e, e, e, e, e, e, f, f, f, f, f, f, g, g, g, g, g, g, g, h, h, h, h, h, h, h, h, i, i, i, i, i, j, j, j, j, j, k, k, k, k, k, k, k, l, l, l, l, l, m, m, m, m, m, m, n, n, n, n, n, n, n, n, n, o, o, o, o, o, o, o, o, p, p, p, p, q, q, q, r, r, s, s, s, s, s, s, t, t, t, t, t, u, u, u, u, u, v, v, v, v, v, v, w, w, w, w, w, w, x, x, x, x, x, x, x, y, y, y, z, z, z, z, z, z
# + emce,evii,fomowsjt,goxmh,hnslwh,jyfv,lvkxunfgez,mtuqvipmh,nlsnoaktsk,pizgtcjoe,pxonajksw,qgcjpnrfke,srmveh,wzokllnb,yfxyuxug,zgfddxxn,zquwod
#  : Should be emce,evii,fomowsjt,goxmh,hnslwh,jyfv,lvkxunfgez,mtuqvipmh,nlsnoaktsk,pizgtcjoe,pxonajksw,qgcjpnrfke,srmveh,wzokllnb,yfxyuxug,zgfddxxn,zquwod
#
# ======================================================================
# FAIL: runTest (testing.test_alpha.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\isabel.lopes\OneDrive - XPLOR SOLUTIONS\PythonForAISolutions\WEEK2\Functions\testing.py", line 187, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: ', , , , , , , , , , , , , , , , , , , , ,[632 chars]z, z' != 'aduqrezqgr,ahfmcj,bifas,cmnzlzgbk,dahbber[166 chars]eqfk'
# Diff is 895 characters long. Set self.maxDiff to None to see it. : Should be aduqrezqgr,ahfmcj,bifas,cmnzlzgbk,dahbbermmi,dwhwubsu,fufzctj,fwnz,hrdf,jrhy,laaehuynsr,lwodqadygx,mfxprijk,nrta,perldaxnk,qtrdepy,sgjwaewsqt,tchxruvbd,vgkxaslyrc,vhclryioni,wasjbmyja,wfdocolzn,ybyojuc,zcrdieqfk
#
# ======================================================================
# FAIL: runTest (testing.test_alpha.<locals>.TestKnown.runTest)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\isabel.lopes\OneDrive - XPLOR SOLUTIONS\PythonForAISolutions\WEEK2\Functions\testing.py", line 187, in runTest
#     self.assertEqual(fn(self.input), self.output, f"Should be {self.output}")
# AssertionError: ', , , , , , , , , , , , a, a, a, a, a, a,[304 chars]z, z' != 'ftaqzjiuzm,ggqt,hiwscbxrl,hkqbota,iyfjrwd[64 chars]isoq'
# - , , , , , , , , , , , , a, a, a, a, a, a, a, b, b, b, b, c, c, d, d, f, f, f, g, g, g, h, h, i, i, i, i, i, j, j, j, j, j, k, l, l, l, l, m, m, m, m, m, n, n, n, n, o, o, o, p, q, q, q, q, q, q, r, r, r, r, r, r, r, s, s, s, s, s, s, s, s, t, t, t, t, t, t, u, u, u, u, v, v, v, w, w, w, w, w, x, x, x, y, y, y, y, y, y, z, z, z, z, z, z, z, z, z, z
# + ftaqzjiuzm,ggqt,hiwscbxrl,hkqbota,iyfjrwdmn,jyzbpjfd,jzwcsv,qiyaonux,rygwmur,sbnmzvza,trltsuylz,wsas,zyrzisoq
#  : Should be ftaqzjiuzm,ggqt,hiwscbxrl,hkqbota,iyfjrwdmn,jyzbpjfd,jzwcsv,qiyaonux,rygwmur,sbnmzvza,trltsuylz,wsas,zyrzisoq
#
# ----------------------------------------------------------------------
# Ran 100 tests in 0.325s
#
# FAILED (failures=100)

# %% [markdown]
# ## 12. Write a function to check if a given password is strong (at least 8 characters, at least one lower case, at least one upper case, at least one number and at least one special character). It should output True if strong and False if not.

# %%
def check_pass(password):
#your code here

    
    has_lower = False
    has_upper = False
    has_digit = False
    has_special = False
    special_characters = "@$!%*?&#_-,;'{}()[]€$"

    # Check the length of the password
    length = 0
    for char in password:
        length += 1

    if length < 8:
        return False

    # Check for at least one lowercase letter, one uppercase letter, one digit, and one special character
    for char in password:
        if char.islower():
            has_lower = True
        elif char.isupper():
            has_upper = True
        elif char.isdigit():
            has_digit = True
        elif char in special_characters:
            has_special = True

    # Return True if all conditions are met, else False
    if has_lower and has_upper and has_digit and has_special:
        return True
    else:
        return False

# %%
# This will test your function 
test_pass(check_pass)
# Out:
# ....................................................................................................
# ----------------------------------------------------------------------
# Ran 100 tests in 0.256s
#
# OK
